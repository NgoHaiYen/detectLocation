# %%
from pymongo import MongoClient

client = MongoClient('192.168.9.169', 27017)

db = client.Fb_Raw

location = db.Fb_Location

# %%
def remove_accents(input_str):
    s1 = u'ÀÁÂÃÈÉÊÌÍÒÓÔÕÙÚÝàáâãèéêìíòóôõùúýĂăĐđĨĩŨũƠơƯưẠạẢảẤấẦầẨẩẪẫẬậẮắẰằẲẳẴẵẶặẸẹẺẻẼẽẾếỀềỂểỄễỆệỈỉỊịỌọỎỏỐốỒồỔổỖỗỘộỚớỜờỞởỠỡỢợỤụỦủỨứỪừỬửỮữỰựỲỳỴỵỶỷỸỹ'
    s0 = u'AAAAEEEIIOOOOUUYaaaaeeeiioooouuyAaDdIiUuOoUuAaAaAaAaAaAaAaAaAaAaAaAaEeEeEeEeEeEeEeEeIiIiOoOoOoOoOoOoOoOoOoOoOoOoUuUuUuUuUuUuUuYyYyYyYy'
    s = ''
    for c in input_str:
        if c in s1:
            s += s0[s1.index(c)]
        else:
            s += c
    return s

# %%
def clean(string):
    newItem = remove_accents(string)
    newItem = newItem.lower()
    newItem = newItem.replace(" ", "")
    return newItem

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)
    if len(s2) == 0:
        return len(s1)

    s1 = clean(s1)
    s2 = clean(s2)
    
    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 
            deletions = current_row[j] + 1       
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

# %%
hihi = 0
class Node:
    nodeId = 0
    parent = None
    children = []
    items = set()
    
    def setParent(self, node):
        self.parent = node
        
    def setChildren(self, nodes):
        self.children = nodes
        
    def addItem(self, node):
        self.items.add(node)
        
    def setItem(self, nodes):
        self.items = nodes
        
    def __str__(self):
        st = "\n" + str(self.nodeId) + ": " + str(self.items) + "\n" + "Children of " + str(list(self.items)[0]) + ": " 
        if (len(self.children) > 0):
            for c in self.children:
                st += str(c) + "\n"
        return st
    
    def toDict(self):
        itsDict = dict()
        children = []
        for c in self.children:
            children.append(c.toDict())
        itsDict[list(self.items)[0]] = children
        return itsDict
    
    def __init__(self):
        global hihi
        self.nodeId = hihi
        self.items = set()
        self.parent = None
        self.children = []
        hihi +=1
    
    def numOfCharacter(self):
        sum = 0
        for i in self.items:
            sum += len(i)
        return sum
    
    def distance(self, item):
        sum = 0
        for i in self.items:
            sum += levenshtein(i, item)
        return sum/self.numOfCharacter()
    
    def satisfy(self, word, threshold):
        if word is None:
            return False
        if remove_accents(word) in remove_accents(str(self.items)):
            return True
        elif self.distance(word) < threshold:
            return True
        return False
    
    def satisfy2(self, word, threshold):
        for n in self.children:
            if n.satisfy(word, threshold):
                return n

# %%
def getNumberOfElement(listGroup):
    sum = 0
    for group in listGroup:
        sum += len(group.items)
    return sum

import random
def getOne(available):
    value = random.uniform(0.0, 1.0)
    n = getNumberOfElement(available)
    total = 0
    for a in available:
        total += len(a.items)/n
        if (total >= value):
            return a.nodeId
        
def findNodeById(nodes, nodeId):
    for i in range(len(nodes)):
        if nodes[i].nodeId == nodeId:
            return i

# %%
# chance = True --> find the children of node
def fit(g, value, threshold, chance = False):
    input_str = value.get("name").replace("[", "").replace("]", "")
    s = input_str.split(", ")
    s = s[::-1]
    
    available = []
    for n in g:
        if (not chance) and n.satisfy(s[0], threshold):
            available.append(n)
        elif chance and n.satisfy2(s[0], threshold):
            available.append(n)
    if len(available) == 1:
        if not chance:
            available[0].addItem(s[0])
            if len(s) > 1:
                s.remove(s[0])
                s = s[::-1]
                value["name"] = str(s).replace("\'", "")
                available[0].children = fit(available[0].children, value, threshold)
        else:
            available[0] = fit(available[0].children, value, threshold)
    elif len(available) == 0:
        if chance:
            nodes = []
            for i in range(len(s)):
                node = Node()
                node.addItem(s[i])
                if i != 0:
                    node.parent = nodes[i-1]
                    nodes[i-1].children.append(node)
                nodes.append(node) 
            g.append(nodes[0])
        else:
            g = fit(g, value, threshold, True)

    elif len(available) > 1:
        a = findNodeById(g, getOne(available))
        g[a].addItem(s[0])
#     todo check children of available
                
    return g

# %%
g = []
hihi = 0
threshold = 0.2
data = location.find().limit(1000)
import time
start = time.time()
for d in data:
    g = fit(g, d, threshold)
end = time.time()
print(end-start)
# Out:
# {'_id': '106388046062960', 'name': 'Hanoi, Vietnam'}
# {'_id': '106388046062960', 'name': 'Hanoi, Vietnam'}
# {'_id': '110434555644115', 'name': 'Nam Truc'}
# {'_id': '110434555644115', 'name': 'Nam Truc'}
# {'_id': '108458769184495', 'name': 'Ho Chi Minh City, Vietnam'}
# {'_id': '108458769184495', 'name': '[Ho Chi Minh City]'}
# {'_id': '108458769184495', 'name': '[Ho Chi Minh City]'}
# {'_id': '103934556308311', 'name': 'Hải Dương'}
# {'_id': '103934556308311', 'name': 'Hải Dương'}
# {'_id': '113393768672172', 'name': 'Tuyên Quang, Tuyên Quang, Vietnam'}
# {'_id': '113393768672172', 'name': '[Tuyên Quang, Tuyên Quang]'}
# {'_id': '113393768672172', 'name': '[Tuyên Quang, Tuyên Quang]'}
# {'_id': '100243430017590', 'name': 'Nam Định, Nam Định, Vietnam'}
# {'_id': '100243430017590', 'name': '[Nam Định, Nam Định]'}
# {'_id': '100243430017590', 'name': '[Nam Định, Nam Định]'}
# {'_id': '111711568847056', 'name': 'Da Nang, Vietnam'}
# {'_id': '111711568847056', 'name': '[Da Nang]'}
# {'_id': '111711568847056', 'name': '[Da Nang]'}
# {'_id': '351759091676222', 'name': 'Biên Hòa'}
# {'_id': '351759091676222', 'name': 'Biên Hòa'}
# {'_id': '109311335759536', 'name': 'Thái Bình, Thái Bình, Vietnam'}
# {'_id': '109311335759536', 'name': '[Thái Bình, Thái Bình]'}
# {'_id': '109311335759536', 'name': '[Thái Bình, Thái Bình]'}
# {'_id': '109497189069518', 'name': 'Lạng Sơn'}
# {'_id': '109497189069518', 'name': 'Lạng Sơn'}
# {'_id': '112531495426126', 'name': 'Cà Mau'}
# {'_id': '112531495426126', 'name': 'Cà Mau'}
# {'_id': '110469458975062', 'name': 'Can Duoc'}
# {'_id': '110469458975062', 'name': 'Can Duoc'}
# {'_id': '108162225878454', 'name': 'Cao Bang'}
# {'_id': '108162225878454', 'name': 'Cao Bang'}
# {'_id': '110765362279102', 'name': 'Taipei, Taiwan'}
# {'_id': '110765362279102', 'name': 'Taipei, Taiwan'}
# {'_id': '114668461883395', 'name': 'Hai Phong, Vietnam'}
# {'_id': '114668461883395', 'name': '[Hai Phong]'}
# {'_id': '114668461883395', 'name': '[Hai Phong]'}
# {'_id': '107204132650975', 'name': 'Vàm Rầy (1), Kiến Giang, Vietnam'}
# {'_id': '107204132650975', 'name': '[Vàm Rầy (1), Kiến Giang]'}
# {'_id': '107204132650975', 'name': '[Vàm Rầy (1), Kiến Giang]'}
# {'_id': '108157059219208', 'name': 'Benin, Nigeria'}
# {'_id': '108157059219208', 'name': 'Benin, Nigeria'}
# {'_id': '107751605926185', 'name': 'Hue, Vietnam'}
# {'_id': '107751605926185', 'name': '[Hue]'}
# {'_id': '107751605926185', 'name': '[Hue]'}
# {'_id': '110429408985819', 'name': 'Ninh Bình'}
# {'_id': '110429408985819', 'name': 'Ninh Bình'}
# {'_id': '111611588867416', 'name': 'Djrott, Lâm Ðồng, Vietnam'}
# {'_id': '111611588867416', 'name': '[Djrott, Lâm Ðồng]'}
# {'_id': '111611588867416', 'name': '[Djrott, Lâm Ðồng]'}
# {'_id': '109812039042677', 'name': 'Ha-Nam, Hà Nam, Vietnam'}
# {'_id': '109812039042677', 'name': '[Ha-Nam, Hà Nam]'}
# {'_id': '109812039042677', 'name': '[Ha-Nam, Hà Nam]'}
# {'_id': '106451339392117', 'name': 'Nghi Loc'}
# {'_id': '106451339392117', 'name': 'Nghi Loc'}
# {'_id': '113391222009657', 'name': 'Hung Nhan, Thái Bình, Vietnam'}
# {'_id': '113391222009657', 'name': '[Hung Nhan, Thái Bình]'}
# {'_id': '113391222009657', 'name': '[Hung Nhan]'}
# {'_id': '113391222009657', 'name': '[Hung Nhan]'}
# {'_id': '106078429431815', 'name': 'London, United Kingdom'}
# {'_id': '106078429431815', 'name': 'London, United Kingdom'}
# {'_id': '112963075384670', 'name': 'Vinh'}
# {'_id': '112963075384670', 'name': 'Vinh'}
# {'_id': '110585945628334', 'name': 'Bangkok, Thailand'}
# {'_id': '110585945628334', 'name': 'Bangkok, Thailand'}
# {'_id': '112232812122532', 'name': 'Lucea, Jamaica'}
# {'_id': '112232812122532', 'name': 'Lucea, Jamaica'}
# {'_id': '108611459168961', 'name': 'Mai Dich, Ha Noi, Vietnam'}
# {'_id': '108611459168961', 'name': '[Mai Dich, Ha Noi]'}
# {'_id': '108611459168961', 'name': '[Mai Dich]'}
# {'_id': '108611459168961', 'name': '[Mai Dich]'}
# {'_id': '104973222872461', 'name': 'Phan Rang-Tháp Chàm, Ninh Thuận, Vietnam'}
# {'_id': '104973222872461', 'name': '[Phan Rang-Tháp Chàm, Ninh Thuận]'}
# {'_id': '104973222872461', 'name': '[Phan Rang-Tháp Chàm, Ninh Thuận]'}
# {'_id': '109659755724738', 'name': 'Buôn Ma Thuột, Đắc Lắk, Vietnam'}
# {'_id': '109659755724738', 'name': '[Buôn Ma Thuột, Đắc Lắk]'}
# {'_id': '109659755724738', 'name': '[Buôn Ma Thuột, Đắc Lắk]'}
# {'_id': '106307722741104', 'name': 'Denpasar, Bali, Indonesia'}
# {'_id': '106307722741104', 'name': 'Denpasar, Bali, Indonesia'}
# {'_id': '111175118906315', 'name': 'Berlin, Germany'}
# {'_id': '111175118906315', 'name': 'Berlin, Germany'}
# {'_id': '115357638478734', 'name': 'Rach Gia'}
# {'_id': '115357638478734', 'name': 'Rach Gia'}
# {'_id': '105715936129053', 'name': 'Charlotte, North Carolina'}
# {'_id': '105715936129053', 'name': 'Charlotte, North Carolina'}
# {'_id': '110570212303206', 'name': 'Lombok, Nusa Tenggara Barat, Indonesia'}
# {'_id': '110570212303206', 'name': '[Lombok, Nusa Tenggara Barat]'}
# {'_id': '110570212303206', 'name': '[Lombok, Nusa Tenggara Barat]'}
# {'_id': '110320012326940', 'name': 'Chai Badan, Lop Buri, Thailand'}
# {'_id': '110320012326940', 'name': '[Chai Badan, Lop Buri]'}
# {'_id': '110320012326940', 'name': '[Chai Badan, Lop Buri]'}
# {'_id': '113463568666299', 'name': "Les Saintes Maries De La Mer, Provence-Alpes-Cote D'Azur, France"}
# {'_id': '113463568666299', 'name': "Les Saintes Maries De La Mer, Provence-Alpes-Cote D'Azur, France"}
# {'_id': '105977082774327', 'name': 'Harare, Zimbabwe'}
# {'_id': '105977082774327', 'name': 'Harare, Zimbabwe'}
# {'_id': '109772562387752', 'name': 'Thái Hõa, Nghệ An, Vietnam'}
# {'_id': '109772562387752', 'name': '[Thái Hõa, Nghệ An]'}
# {'_id': '109772562387752', 'name': '[Thái Hõa, Nghệ An]'}
# {'_id': '108679969164197', 'name': 'Nghi Xuân'}
# {'_id': '108679969164197', 'name': 'Nghi Xuân'}
# {'_id': '101894823186182', 'name': 'Gia Nghia'}
# {'_id': '101894823186182', 'name': 'Gia Nghia'}
# {'_id': '114829128532877', 'name': 'Hamburg, Germany'}
# {'_id': '114829128532877', 'name': '[Hamburg]'}
# {'_id': '114829128532877', 'name': '[Hamburg]'}
# {'_id': '105667452800809', 'name': 'Thanh Hóa'}
# {'_id': '105667452800809', 'name': 'Thanh Hóa'}
# {'_id': '103122349727472', 'name': 'Pleiku'}
# {'_id': '103122349727472', 'name': 'Pleiku'}
# {'_id': '106288426073331', 'name': 'Tinh Gia'}
# {'_id': '106288426073331', 'name': 'Tinh Gia'}
# {'_id': '105565836144069', 'name': 'Singapore'}
# {'_id': '105565836144069', 'name': 'Singapore'}
# {'_id': '110512632303092', 'name': 'Vĩnh Long'}
# {'_id': '110512632303092', 'name': 'Vĩnh Long'}
# {'_id': '110352975652476', 'name': 'Macao, China'}
# {'_id': '110352975652476', 'name': 'Macao, China'}
# {'_id': '108536245843925', 'name': 'Hà Tĩnh'}
# {'_id': '108536245843925', 'name': 'Hà Tĩnh'}
# {'_id': '105782926129203', 'name': 'Florence, Italy'}
# {'_id': '105782926129203', 'name': 'Florence, Italy'}
# {'_id': '110457042313059', 'name': 'Hung Yen, Hưng Yên, Vietnam'}
# {'_id': '110457042313059', 'name': '[Hung Yen, Hưng Yên]'}
# {'_id': '110457042313059', 'name': '[Hung Yen, Hưng Yên]'}
# {'_id': '112597352084933', 'name': 'Tuy Hòa'}
# {'_id': '112597352084933', 'name': 'Tuy Hòa'}
# {'_id': '106483032720340', 'name': 'Kien Luong'}
# {'_id': '106483032720340', 'name': 'Kien Luong'}
# {'_id': '107198922651583', 'name': 'Nam �Àn, Nghệ An, Vietnam'}
# {'_id': '107198922651583', 'name': '[Nam �Àn, Nghệ An]'}
# {'_id': '107198922651583', 'name': '[Nam �Àn]'}
# {'_id': '107198922651583', 'name': '[Nam �Àn]'}
# {'_id': '111615515528234', 'name': 'Quynh Luu, Nghệ An, Vietnam'}
# {'_id': '111615515528234', 'name': '[Quynh Luu, Nghệ An]'}
# {'_id': '111615515528234', 'name': '[Quynh Luu]'}
# {'_id': '111615515528234', 'name': '[Quynh Luu]'}
# {'_id': '108062092560276', 'name': 'Di An'}
# {'_id': '108062092560276', 'name': 'Di An'}
# {'_id': '108144289218778', 'name': 'Jember'}
# {'_id': '108144289218778', 'name': 'Jember'}
# {'_id': '105469112820027', 'name': 'Tra Vinh'}
# {'_id': '105469112820027', 'name': 'Tra Vinh'}
# {'_id': '113590611986222', 'name': 'Me Tri, Ha Noi, Vietnam'}
# {'_id': '113590611986222', 'name': '[Me Tri, Ha Noi]'}
# {'_id': '113590611986222', 'name': '[Me Tri]'}
# {'_id': '113590611986222', 'name': '[Me Tri]'}
# {'_id': '111403155545903', 'name': 'Can Tho'}
# {'_id': '111403155545903', 'name': 'Can Tho'}
# {'_id': '105744996115527', 'name': 'Ap Binh Duong (1), Vietnam'}
# {'_id': '105744996115527', 'name': '[Ap Binh Duong (1)]'}
# {'_id': '105744996115527', 'name': '[Ap Binh Duong (1)]'}
# {'_id': '113336155343640', 'name': 'Phuket (city)'}
# {'_id': '113336155343640', 'name': 'Phuket (city)'}
# {'_id': '114120778603884', 'name': 'Ben Cat'}
# {'_id': '114120778603884', 'name': 'Ben Cat'}
# {'_id': '109205905763791', 'name': 'Nha Trang'}
# {'_id': '109205905763791', 'name': 'Nha Trang'}
# {'_id': '110412565650832', 'name': "'Aïn Defla, Ain Defla, Algeria"}
# {'_id': '110412565650832', 'name': "'Aïn Defla, Ain Defla, Algeria"}
# {'_id': '107645375935528', 'name': 'Brno, Czech Republic'}
# {'_id': '107645375935528', 'name': 'Brno, Czech Republic'}
# {'_id': '106279826069074', 'name': 'Tây Ninh'}
# {'_id': '106279826069074', 'name': 'Tây Ninh'}
# {'_id': '106031246101831', 'name': 'Kuala Lumpur, Malaysia'}
# {'_id': '106031246101831', 'name': 'Kuala Lumpur, Malaysia'}
# {'_id': '108747619148221', 'name': 'Xa Phan Thiet, Bình Thuận, Vietnam'}
# {'_id': '108747619148221', 'name': '[Xa Phan Thiet, Bình Thuận]'}
# {'_id': '108747619148221', 'name': '[Xa Phan Thiet]'}
# {'_id': '108747619148221', 'name': '[Xa Phan Thiet]'}
# {'_id': '106498672718836', 'name': 'Thu Dau Mot'}
# {'_id': '106498672718836', 'name': 'Thu Dau Mot'}
# {'_id': '114359205246682', 'name': 'Ipoh, Perak'}
# {'_id': '114359205246682', 'name': 'Ipoh, Perak'}
# {'_id': '114629675219759', 'name': 'Manchester, United Kingdom'}
# {'_id': '114629675219759', 'name': '[Manchester]'}
# {'_id': '114629675219759', 'name': '[Manchester]'}
# {'_id': '115502455133721', 'name': 'Vinh Ang, Nghe Tinh, Vietnam'}
# {'_id': '115502455133721', 'name': '[Vinh Ang, Nghe Tinh]'}
# {'_id': '115502455133721', 'name': '[Vinh Ang, Nghe Tinh]'}
# {'_id': '113144145371672', 'name': 'Thanh Bình, Ðồng Tháp, Vietnam'}
# {'_id': '113144145371672', 'name': '[Thanh Bình, Ðồng Tháp]'}
# {'_id': '113144145371672', 'name': '[Thanh Bình, Ðồng Tháp]'}
# {'_id': '107983352568918', 'name': 'Bắc Ninh'}
# {'_id': '107983352568918', 'name': 'Bắc Ninh'}
# {'_id': '109121749121722', 'name': 'Kim Bang, Ha Nam Ninh, Vietnam'}
# {'_id': '109121749121722', 'name': '[Kim Bang, Ha Nam Ninh]'}
# {'_id': '109121749121722', 'name': '[Kim Bang, Ha Nam Ninh]'}
# {'_id': '114259518587734', 'name': 'Binh Luc, Hà Nam, Vietnam'}
# {'_id': '114259518587734', 'name': '[Binh Luc, Hà Nam]'}
# {'_id': '448443205270045', 'name': 'Bao Loc'}
# {'_id': '448443205270045', 'name': 'Bao Loc'}
# {'_id': '108138999213669', 'name': 'Điện Biên Phủ'}
# {'_id': '108138999213669', 'name': 'Điện Biên Phủ'}
# {'_id': '107862399246929', 'name': 'Yên Thành'}
# {'_id': '107862399246929', 'name': 'Yên Thành'}
# {'_id': '115351105145884', 'name': 'Cairo, Egypt'}
# {'_id': '115351105145884', 'name': 'Cairo, Egypt'}
# {'_id': '107799302587452', 'name': 'Tan Ky'}
# {'_id': '107799302587452', 'name': 'Tan Ky'}
# {'_id': '107812615908638', 'name': 'Greensboro, North Carolina'}
# {'_id': '107812615908638', 'name': '[Greensboro]'}
# {'_id': '107812615908638', 'name': '[Greensboro]'}
# {'_id': '108079539226566', 'name': 'Dak Mil'}
# {'_id': '108079539226566', 'name': 'Dak Mil'}
# {'_id': '108525715838806', 'name': 'Malang'}
# {'_id': '108525715838806', 'name': 'Malang'}
# {'_id': '115411458475455', 'name': 'Ap Bao Binh, Vietnam'}
# {'_id': '115411458475455', 'name': '[Ap Bao Binh]'}
# {'_id': '115411458475455', 'name': '[Ap Bao Binh]'}
# {'_id': '108479165840750', 'name': 'Rajshahi'}
# {'_id': '108479165840750', 'name': 'Rajshahi'}
# {'_id': '108918285804681', 'name': 'Cần Giờ, Hồ Chí Minh, Vietnam'}
# {'_id': '108918285804681', 'name': '[Cần Giờ, Hồ Chí Minh]'}
# {'_id': '108918285804681', 'name': '[Cần Giờ]'}
# {'_id': '108918285804681', 'name': '[Cần Giờ]'}
# {'_id': '110543998972654', 'name': 'Bumi Serpong, Jawa Barat, Indonesia'}
# {'_id': '110543998972654', 'name': '[Bumi Serpong, Jawa Barat]'}
# {'_id': '110543998972654', 'name': '[Bumi Serpong, Jawa Barat]'}
# {'_id': '103998542969809', 'name': 'Thái Nguyên'}
# {'_id': '103998542969809', 'name': 'Thái Nguyên'}
# {'_id': '110041405685472', 'name': 'Vung Tau'}
# {'_id': '110041405685472', 'name': 'Vung Tau'}
# {'_id': '108121405876426', 'name': 'Da Lat'}
# {'_id': '108121405876426', 'name': 'Da Lat'}
# {'_id': '114392968570855', 'name': 'Hòa Bình, Hòa Bình, Vietnam'}
# {'_id': '114392968570855', 'name': '[Hòa Bình, Hòa Bình]'}
# {'_id': '114392968570855', 'name': '[Hòa Bình, Hòa Bình]'}
# {'_id': '111577152196968', 'name': 'My Loc, Ha Nam Ninh, Vietnam'}
# {'_id': '111577152196968', 'name': '[My Loc, Ha Nam Ninh]'}
# {'_id': '111577152196968', 'name': '[My Loc]'}
# {'_id': '111577152196968', 'name': '[My Loc]'}
# {'_id': '112333758781159', 'name': 'Long Xuyên'}
# {'_id': '112333758781159', 'name': 'Long Xuyên'}
# {'_id': '110920568928263', 'name': 'Long Thanh'}
# {'_id': '110920568928263', 'name': 'Long Thanh'}
# {'_id': '104872059549753', 'name': 'Tasek Glugor, Pulau Pinang, Malaysia'}
# {'_id': '104872059549753', 'name': '[Tasek Glugor, Pulau Pinang]'}
# {'_id': '104872059549753', 'name': '[Tasek Glugor, Pulau Pinang]'}
# {'_id': '108843092470023', 'name': 'Tanahgrogot, Kalimantan Timur, Indonesia'}
# {'_id': '108843092470023', 'name': '[Tanahgrogot, Kalimantan Timur]'}
# {'_id': '108843092470023', 'name': '[Tanahgrogot, Kalimantan Timur]'}
# {'_id': '101889586519301', 'name': 'Dhaka, Bangladesh'}
# {'_id': '101889586519301', 'name': 'Dhaka, Bangladesh'}
# {'_id': '109167735769857', 'name': 'Bac Giang'}
# {'_id': '109167735769857', 'name': 'Bac Giang'}
# {'_id': '109375022413858', 'name': 'Debrecen'}
# {'_id': '109375022413858', 'name': 'Debrecen'}
# {'_id': '110136522349903', 'name': 'Binh Chuan, Song Be, Vietnam'}
# {'_id': '110136522349903', 'name': '[Binh Chuan, Song Be]'}
# {'_id': '110136522349903', 'name': '[Binh Chuan, Song Be]'}
# {'_id': '110161112345635', 'name': 'Quang Ngai'}
# {'_id': '110161112345635', 'name': 'Quang Ngai'}
# {'_id': '108027062558523', 'name': 'Toshima, Tokyo'}
# {'_id': '108027062558523', 'name': 'Toshima, Tokyo'}
# {'_id': '111628348854225', 'name': 'Lào Cai'}
# {'_id': '111628348854225', 'name': 'Lào Cai'}
# {'_id': '108343052523582', 'name': 'Davao City'}
# {'_id': '108343052523582', 'name': 'Davao City'}
# {'_id': '113317605345751', 'name': 'Hong Kong'}
# {'_id': '113317605345751', 'name': 'Hong Kong'}
# {'_id': '115213835158481', 'name': 'Phan Thiet'}
# {'_id': '115213835158481', 'name': 'Phan Thiet'}
# {'_id': '108252552529332', 'name': 'Perth, Western Australia'}
# {'_id': '108252552529332', 'name': 'Perth, Western Australia'}
# {'_id': '104828462886008', 'name': "Ha Tin', Hà Tĩnh, Vietnam"}
# {'_id': '104828462886008', 'name': '["Ha Tin", Hà Tĩnh]'}
# {'_id': '104828462886008', 'name': '["Ha Tin", Hà Tĩnh]'}
# {'_id': '112968642062008', 'name': 'Quang Giao, Ha Tuyen, Vietnam'}
# {'_id': '112968642062008', 'name': '[Quang Giao, Ha Tuyen]'}
# {'_id': '112968642062008', 'name': '[Quang Giao, Ha Tuyen]'}
# {'_id': '107966492570582', 'name': 'Xuan Truong'}
# {'_id': '107966492570582', 'name': 'Xuan Truong'}
# {'_id': '104911886212799', 'name': 'Ha Loi, Ha Noi, Vietnam'}
# {'_id': '104911886212799', 'name': '[Ha Loi, Ha Noi]'}
# {'_id': '104911886212799', 'name': '[Ha Loi]'}
# {'_id': '104911886212799', 'name': '[Ha Loi]'}
# {'_id': '104676639570541', 'name': 'Yeniköy, Istanbul, Turkey'}
# {'_id': '104676639570541', 'name': 'Yeniköy, Istanbul, Turkey'}
# {'_id': '107446829285335', 'name': 'Hà Giang'}
# {'_id': '107446829285335', 'name': 'Hà Giang'}
# {'_id': '106502519386806', 'name': 'Budapest, Hungary'}
# {'_id': '106502519386806', 'name': 'Budapest, Hungary'}
# {'_id': '114461521904650', 'name': 'Moc Chau'}
# {'_id': '114461521904650', 'name': 'Moc Chau'}
# {'_id': '114159085260961', 'name': 'Ninh Hòa, Khánh Hòa, Vietnam'}
# {'_id': '114159085260961', 'name': '[Ninh Hòa, Khánh Hòa]'}
# {'_id': '114159085260961', 'name': '[Ninh Hòa, Khánh Hòa]'}
# {'_id': '106300959405546', 'name': 'Minneapolis, Minnesota'}
# {'_id': '106300959405546', 'name': 'Minneapolis, Minnesota'}
# {'_id': '111117635579016', 'name': 'Ha Long'}
# {'_id': '111117635579016', 'name': 'Ha Long'}
# {'_id': '112502942098760', 'name': 'Paris, Texas'}
# {'_id': '112502942098760', 'name': 'Paris, Texas'}
# {'_id': '106522539380517', 'name': 'Tinh, Sóc Trăng, Vietnam'}
# {'_id': '106522539380517', 'name': '[Tinh, Sóc Trăng]'}
# {'_id': '106522539380517', 'name': '[Tinh, Sóc Trăng]'}
# {'_id': '113135802045540', 'name': 'Tam Đảo, Vĩnh Phúc, Vietnam'}
# {'_id': '113135802045540', 'name': '[Tam Đảo, Vĩnh Phúc]'}
# {'_id': '113135802045540', 'name': '[Tam Đảo, Vĩnh Phúc]'}
# {'_id': '110774245616525', 'name': 'Paris, France'}
# {'_id': '110774245616525', 'name': '[Paris]'}
# {'_id': '110774245616525', 'name': '[Paris]'}
# {'_id': '111167958906145', 'name': 'Thoi Lai, Vietnam'}
# {'_id': '111167958906145', 'name': '[Thoi Lai]'}
# {'_id': '111167958906145', 'name': '[Thoi Lai]'}
# {'_id': '109477335744202', 'name': 'Quang Nam, Quang Nam-Da Nang, Vietnam'}
# {'_id': '109477335744202', 'name': '[Quang Nam, Quang Nam-Da Nang]'}
# {'_id': '109477335744202', 'name': '[Quang Nam, Quang Nam-Da Nang]'}
# {'_id': '106429506060405', 'name': 'Phú Quý'}
# {'_id': '106429506060405', 'name': 'Phú Quý'}
# {'_id': '113185112026839', 'name': 'Bình Chánh, Hồ Chí Minh, Vietnam'}
# {'_id': '113185112026839', 'name': '[Bình Chánh, Hồ Chí Minh]'}
# {'_id': '113185112026839', 'name': '[Bình Chánh]'}
# {'_id': '113185112026839', 'name': '[Bình Chánh]'}
# {'_id': '106371322730906', 'name': 'Bon Bu Bo Dak Nong, Đắc Lắk, Vietnam'}
# {'_id': '106371322730906', 'name': '[Bon Bu Bo Dak Nong, Đắc Lắk]'}
# {'_id': '106371322730906', 'name': '[Bon Bu Bo Dak Nong]'}
# {'_id': '106371322730906', 'name': '[Bon Bu Bo Dak Nong]'}
# {'_id': '100248110017068', 'name': 'Hóc Môn, Hồ Chí Minh, Vietnam'}
# {'_id': '100248110017068', 'name': '[Hóc Môn, Hồ Chí Minh]'}
# {'_id': '100248110017068', 'name': '[Hóc Môn]'}
# {'_id': '100248110017068', 'name': '[Hóc Môn]'}
# {'_id': '113481995334323', 'name': 'Vien Chang, Vientiane, Laos'}
# {'_id': '113481995334323', 'name': 'Vien Chang, Vientiane, Laos'}
# {'_id': '105805556137674', 'name': 'Karbi Anglong, India'}
# {'_id': '105805556137674', 'name': 'Karbi Anglong, India'}
# {'_id': '108169082548939', 'name': 'Bến Tre'}
# {'_id': '108169082548939', 'name': 'Bến Tre'}
# {'_id': '108192712546684', 'name': 'Đồng Hới'}
# {'_id': '108192712546684', 'name': 'Đồng Hới'}
# {'_id': '105371042830323', 'name': 'Kanoya, Kagoshima'}
# {'_id': '105371042830323', 'name': 'Kanoya, Kagoshima'}
# {'_id': '105773999462846', 'name': 'Tam Ky'}
# {'_id': '103767749662650', 'name': 'Tân Phú'}
# {'_id': '103767749662650', 'name': 'Tân Phú'}
# {'_id': '108981799125381', 'name': 'Long An, Tiền Giang, Vietnam'}
# {'_id': '108981799125381', 'name': '[Long An, Tiền Giang]'}
# {'_id': '108981799125381', 'name': '[Long An]'}
# {'_id': '108981799125381', 'name': '[Long An]'}
# {'_id': '133571830058631', 'name': 'Quảng Trị'}
# {'_id': '133571830058631', 'name': 'Quảng Trị'}
# {'_id': '111520935533848', 'name': 'Buon Me Thuot'}
# {'_id': '111520935533848', 'name': 'Buon Me Thuot'}
# {'_id': '108259475871818', 'name': 'Seoul, Korea'}
# {'_id': '108259475871818', 'name': 'Seoul, Korea'}
# {'_id': '106301249409221', 'name': 'Ben Luc'}
# {'_id': '106301249409221', 'name': 'Ben Luc'}
# {'_id': '110884905606108', 'name': 'Sydney, Australia'}
# {'_id': '110884905606108', 'name': '[Sydney]'}
# {'_id': '110884905606108', 'name': '[Sydney]'}
# {'_id': '108724149156796', 'name': 'Thành phố Hồ Chí Minh, Hồ Chí Minh, Vietnam'}
# {'_id': '108724149156796', 'name': '[Thành phố Hồ Chí Minh, Hồ Chí Minh]'}
# {'_id': '108724149156796', 'name': '[Thành phố Hồ Chí Minh]'}
# {'_id': '108724149156796', 'name': '[Thành phố Hồ Chí Minh]'}
# {'_id': '105823282791353', 'name': 'Hàm Yên'}
# {'_id': '105823282791353', 'name': 'Hàm Yên'}
# {'_id': '104690386236592', 'name': 'Go Vap, Hồ Chí Minh, Vietnam'}
# {'_id': '104690386236592', 'name': '[Go Vap, Hồ Chí Minh]'}
# {'_id': '104690386236592', 'name': '[Go Vap]'}
# {'_id': '104690386236592', 'name': '[Go Vap]'}
# {'_id': '104043839631933', 'name': 'Son La'}
# {'_id': '104043839631933', 'name': 'Son La'}
# {'_id': '106497972719166', 'name': 'Anh Son'}
# {'_id': '106497972719166', 'name': 'Anh Son'}
# {'_id': '107993685900141', 'name': 'Viet Tri'}
# {'_id': '107993685900141', 'name': 'Viet Tri'}
# {'_id': '102152049827030', 'name': 'Makati'}
# {'_id': '102152049827030', 'name': 'Makati'}
# {'_id': '116332251714435', 'name': 'Mitho, Tiền Giang, Vietnam'}
# {'_id': '116332251714435', 'name': '[Mitho, Tiền Giang]'}
# {'_id': '116332251714435', 'name': '[Mitho]'}
# {'_id': '116332251714435', 'name': '[Mitho]'}
# {'_id': '114356225247246', 'name': 'Tuong Duong'}
# {'_id': '114356225247246', 'name': 'Tuong Duong'}
# {'_id': '104904439545800', 'name': 'Plây Ku, Gia Lai, Vietnam'}
# {'_id': '104904439545800', 'name': '[Plây Ku, Gia Lai]'}
# {'_id': '104904439545800', 'name': '[Plây Ku, Gia Lai]'}
# {'_id': '113483512000061', 'name': 'Hoai Duc Phu, Ha Noi, Vietnam'}
# {'_id': '113483512000061', 'name': '[Hoai Duc Phu, Ha Noi]'}
# {'_id': '113483512000061', 'name': '[Hoai Duc Phu]'}
# {'_id': '113483512000061', 'name': '[Hoai Duc Phu]'}
# {'_id': '108203205880819', 'name': 'Duy Xuyên'}
# {'_id': '108203205880819', 'name': 'Duy Xuyên'}
# {'_id': '102173726491792', 'name': 'Jakarta, Indonesia'}
# {'_id': '102173726491792', 'name': '[Jakarta]'}
# {'_id': '102173726491792', 'name': '[Jakarta]'}
# {'_id': '112027728823762', 'name': 'Indore, India'}
# {'_id': '112027728823762', 'name': '[Indore]'}
# {'_id': '112027728823762', 'name': '[Indore]'}
# {'_id': '113000728715623', 'name': 'Po Ly Hgai, Ha Tuyen, Vietnam'}
# {'_id': '113000728715623', 'name': '[Po Ly Hgai, Ha Tuyen]'}
# {'_id': '113000728715623', 'name': '[Po Ly Hgai]'}
# {'_id': '113000728715623', 'name': '[Po Ly Hgai]'}
# {'_id': '104011556303312', 'name': 'Hamilton, Ontario'}
# {'_id': '104011556303312', 'name': 'Hamilton, Ontario'}
# {'_id': '109800982364415', 'name': 'Gia Kiem, Vietnam'}
# {'_id': '109800982364415', 'name': '[Gia Kiem]'}
# {'_id': '109800982364415', 'name': '[Gia Kiem]'}
# {'_id': '109447862413880', 'name': 'Haidöng, Hải Dương, Vietnam'}
# {'_id': '109447862413880', 'name': '[Haidöng, Hải Dương]'}
# {'_id': '109447862413880', 'name': '[Haidöng, Hải Dương]'}
# {'_id': '112077065484753', 'name': 'Vinh Tuong'}
# {'_id': '112077065484753', 'name': 'Vinh Tuong'}
# {'_id': '112031942146527', 'name': 'Dong Ha'}
# {'_id': '112031942146527', 'name': 'Dong Ha'}
# {'_id': '109888412374190', 'name': 'My Tho'}
# {'_id': '109888412374190', 'name': 'My Tho'}
# {'_id': '110076682348141', 'name': 'Phan Rang'}
# {'_id': '110076682348141', 'name': 'Phan Rang'}
# {'_id': '116190411724975', 'name': 'Melbourne, Victoria, Australia'}
# {'_id': '116190411724975', 'name': '[Melbourne, Victoria]'}
# {'_id': '116190411724975', 'name': '[Melbourne, Victoria]'}
# {'_id': '108733339154438', 'name': 'Bồng Sơn, Bình Ðịnh, Vietnam'}
# {'_id': '108733339154438', 'name': '[Bồng Sơn, Bình Ðịnh]'}
# {'_id': '108733339154438', 'name': '[Bồng Sơn, Bình Ðịnh]'}
# {'_id': '113138805364947', 'name': 'Phu Dien Chau, Nghệ An, Vietnam'}
# {'_id': '113138805364947', 'name': '[Phu Dien Chau, Nghệ An]'}
# {'_id': '113138805364947', 'name': '[Phu Dien Chau]'}
# {'_id': '113138805364947', 'name': '[Phu Dien Chau]'}
# {'_id': '108242839208810', 'name': 'Cao Lãnh'}
# {'_id': '108242839208810', 'name': 'Cao Lãnh'}
# {'_id': '116405215039665', 'name': 'Kon Tum, Kon Tum, Vietnam'}
# {'_id': '116405215039665', 'name': '[Kon Tum, Kon Tum]'}
# {'_id': '116405215039665', 'name': '[Kon Tum, Kon Tum]'}
# {'_id': '111244068899165', 'name': 'Le Thuy, Quảng Bình, Vietnam'}
# {'_id': '111244068899165', 'name': '[Le Thuy, Quảng Bình]'}
# {'_id': '111244068899165', 'name': '[Le Thuy, Quảng Bình]'}
# {'_id': '112726978744216', 'name': 'Rach Gia, Vietnam'}
# {'_id': '112726978744216', 'name': '[Rach Gia]'}
# {'_id': '112726978744216', 'name': '[Rach Gia]'}
# {'_id': '109320032425357', 'name': 'Trang Bach, Quảng Ninh, Vietnam'}
# {'_id': '109320032425357', 'name': '[Trang Bach, Quảng Ninh]'}
# {'_id': '109320032425357', 'name': '[Trang Bach]'}
# {'_id': '109320032425357', 'name': '[Trang Bach]'}
# {'_id': '112780328736488', 'name': 'Tân An, Long An'}
# {'_id': '112780328736488', 'name': 'Tân An, Long An'}
# {'_id': '104877562883229', 'name': 'Châu Thành, Tiền Giang, Vietnam'}
# {'_id': '104877562883229', 'name': '[Châu Thành, Tiền Giang]'}
# {'_id': '104877562883229', 'name': '[Châu Thành]'}
# {'_id': '104877562883229', 'name': '[Châu Thành]'}
# {'_id': '106445202713524', 'name': 'Australie, Curaçao'}
# {'_id': '106445202713524', 'name': 'Australie, Curaçao'}
# {'_id': '114104091937642', 'name': 'Oudega, Friesland, Netherlands'}
# {'_id': '114104091937642', 'name': 'Oudega, Friesland, Netherlands'}
# {'_id': '106967662677485', 'name': 'Nghia Ã?An, Nghệ An, Vietnam'}
# {'_id': '106967662677485', 'name': '[Nghia Ã?An, Nghệ An]'}
# {'_id': '106967662677485', 'name': '[Nghia Ã?An]'}
# {'_id': '106967662677485', 'name': '[Nghia Ã?An]'}
# {'_id': '108663825829925', 'name': 'Chaudok, An Giang, Vietnam'}
# {'_id': '108663825829925', 'name': '[Chaudok, An Giang]'}
# {'_id': '108663825829925', 'name': '[Chaudok, An Giang]'}
# {'_id': '109916112357708', 'name': 'Binh Phuoc, Vietnam'}
# {'_id': '109916112357708', 'name': '[Binh Phuoc]'}
# {'_id': '109916112357708', 'name': '[Binh Phuoc]'}
# {'_id': '111510078871628', 'name': 'Phu Lo, Vinh Phu, Vietnam'}
# {'_id': '111510078871628', 'name': '[Phu Lo, Vinh Phu]'}
# {'_id': '111510078871628', 'name': '[Phu Lo]'}
# {'_id': '111510078871628', 'name': '[Phu Lo]'}
# {'_id': '108028762564501', 'name': 'Phú Thọ'}
# {'_id': '108028762564501', 'name': 'Phú Thọ'}
# {'_id': '109155499103263', 'name': 'Cebu City'}
# {'_id': '109155499103263', 'name': 'Cebu City'}
# {'_id': '112168488806891', 'name': 'Hớn Quản, Bìn Phước, Vietnam'}
# {'_id': '112168488806891', 'name': '[Hớn Quản, Bìn Phước]'}
# {'_id': '112168488806891', 'name': '[Hớn Quản]'}
# {'_id': '112168488806891', 'name': '[Hớn Quản]'}
# {'_id': '108422612522293', 'name': 'Luc Nam'}
# {'_id': '108422612522293', 'name': 'Luc Nam'}
# {'_id': '106553719382321', 'name': 'Dalad Qi'}
# {'_id': '106553719382321', 'name': 'Dalad Qi'}
# {'_id': '104055736298447', 'name': 'Lumajang'}
# {'_id': '104055736298447', 'name': 'Lumajang'}
# {'_id': '110473805639090', 'name': 'Vinh Phuc, Ha Noi, Vietnam'}
# {'_id': '110473805639090', 'name': '[Vinh Phuc, Ha Noi]'}
# {'_id': '110473805639090', 'name': '[Vinh Phuc]'}
# {'_id': '110473805639090', 'name': '[Vinh Phuc]'}
# {'_id': '107978652563828', 'name': 'Tangerang'}
# {'_id': '107978652563828', 'name': 'Tangerang'}
# {'_id': '108424279189115', 'name': 'New York, New York'}
# {'_id': '108424279189115', 'name': 'New York, New York'}
# {'_id': '113737778641655', 'name': 'Sangkulirang, Kalimantan Timur, Indonesia'}
# {'_id': '113737778641655', 'name': '[Sangkulirang, Kalimantan Timur]'}
# {'_id': '113737778641655', 'name': '[Sangkulirang]'}
# {'_id': '113737778641655', 'name': '[Sangkulirang]'}
# {'_id': '110666318962176', 'name': 'Bogor, Indonesia'}
# {'_id': '110666318962176', 'name': '[Bogor]'}
# {'_id': '110666318962176', 'name': '[Bogor]'}
# {'_id': '109170555774378', 'name': 'Sigi, Sulawesi Tengah, Indonesia'}
# {'_id': '109170555774378', 'name': '[Sigi, Sulawesi Tengah]'}
# {'_id': '109170555774378', 'name': '[Sigi, Sulawesi Tengah]'}
# {'_id': '111871795504645', 'name': 'Vieh Yen, Vĩnh Phúc, Vietnam'}
# {'_id': '111871795504645', 'name': '[Vieh Yen, Vĩnh Phúc]'}
# {'_id': '111871795504645', 'name': '[Vieh Yen]'}
# {'_id': '111871795504645', 'name': '[Vieh Yen]'}
# {'_id': '112453185438062', 'name': 'Gò Dầu Hạ, Tây Ninh, Vietnam'}
# {'_id': '112453185438062', 'name': '[Gò Dầu Hạ, Tây Ninh]'}
# {'_id': '112453185438062', 'name': '[Gò Dầu Hạ, Tây Ninh]'}
# {'_id': '108729979147301', 'name': 'Hoài Nhon, Bình Ðịnh, Vietnam'}
# {'_id': '108729979147301', 'name': '[Hoài Nhon, Bình Ðịnh]'}
# {'_id': '108729979147301', 'name': '[Hoài Nhon]'}
# {'_id': '108729979147301', 'name': '[Hoài Nhon]'}
# {'_id': '109053269122518', 'name': 'Cẩm Phả Port, Quảng Ninh, Vietnam'}
# {'_id': '109053269122518', 'name': '[Cẩm Phả Port, Quảng Ninh]'}
# {'_id': '109053269122518', 'name': '[Cẩm Phả Port]'}
# {'_id': '109053269122518', 'name': '[Cẩm Phả Port]'}
# {'_id': '111972302153545', 'name': 'Kupang'}
# {'_id': '111972302153545', 'name': 'Kupang'}
# {'_id': '104057952962840', 'name': 'Jászberény'}
# {'_id': '104057952962840', 'name': 'Jászberény'}
# {'_id': '106228946080582', 'name': 'Honjo, Saitama'}
# {'_id': '106228946080582', 'name': 'Honjo, Saitama'}
# {'_id': '110970792260960', 'name': 'Los Angeles, California'}
# {'_id': '110970792260960', 'name': 'Los Angeles, California'}
# {'_id': '108274379200811', 'name': 'Jambi City'}
# {'_id': '108274379200811', 'name': 'Jambi City'}
# {'_id': '110228142339670', 'name': 'Chisinau, Moldova'}
# {'_id': '110228142339670', 'name': 'Chisinau, Moldova'}
# {'_id': '110684188959162', 'name': 'Chandigarh, India'}
# {'_id': '110684188959162', 'name': '[Chandigarh]'}
# {'_id': '110684188959162', 'name': '[Chandigarh]'}
# {'_id': '112199325473595', 'name': 'Tân Uyên'}
# {'_id': '112199325473595', 'name': 'Tân Uyên'}
# {'_id': '109098405791293', 'name': 'Desa'}
# {'_id': '109098405791293', 'name': 'Desa'}
# {'_id': '108737142491685', 'name': 'Long Khanh'}
# {'_id': '115963528414384', 'name': 'Houston, Texas'}
# {'_id': '115963528414384', 'name': '[Houston]'}
# {'_id': '115963528414384', 'name': '[Houston]'}
# {'_id': '110594902293454', 'name': 'Duri, Riau, Indonesia'}
# {'_id': '110594902293454', 'name': '[Duri, Riau]'}
# {'_id': '110594902293454', 'name': '[Duri, Riau]'}
# {'_id': '104096482958990', 'name': 'Tabuk, Saudi Arabia'}
# {'_id': '104096482958990', 'name': 'Tabuk, Saudi Arabia'}
# {'_id': '106041442770197', 'name': 'Astana, Kazakhstan'}
# {'_id': '106041442770197', 'name': 'Astana, Kazakhstan'}
# {'_id': '107968765903327', 'name': 'İzmir, Turkey'}
# {'_id': '107968765903327', 'name': '[İzmir]'}
# {'_id': '107968765903327', 'name': '[İzmir]'}
# {'_id': '108599629164810', 'name': 'Pagadian City'}
# {'_id': '108599629164810', 'name': 'Pagadian City'}
# {'_id': '103847742987074', 'name': 'Bandung'}
# {'_id': '103847742987074', 'name': 'Bandung'}
# {'_id': '115504291797975', 'name': 'Athens, Greece'}
# {'_id': '115504291797975', 'name': 'Athens, Greece'}
# {'_id': '104071219630356', 'name': 'Sanggau'}
# {'_id': '104071219630356', 'name': 'Sanggau'}
# {'_id': '111591762192643', 'name': 'Chiang Mai, Thailand'}
# {'_id': '111591762192643', 'name': '[Chiang Mai]'}
# {'_id': '111591762192643', 'name': '[Chiang Mai]'}
# {'_id': '110378492324625', 'name': 'Fuchu, Tokyo'}
# {'_id': '110378492324625', 'name': '[Fuchu]'}
# {'_id': '110378492324625', 'name': '[Fuchu]'}
# {'_id': '109450692419743', 'name': 'Phu-Li, Hà Nam, Vietnam'}
# {'_id': '109450692419743', 'name': '[Phu-Li, Hà Nam]'}
# {'_id': '112116865470864', 'name': 'Mandalay'}
# {'_id': '112116865470864', 'name': 'Mandalay'}
# {'_id': '107507939267185', 'name': 'Ho Nai, Vietnam'}
# {'_id': '107507939267185', 'name': '[Ho Nai]'}
# {'_id': '107507939267185', 'name': '[Ho Nai]'}
# {'_id': '111697102184848', 'name': 'Banyuwangi, Jawa Timur, Indonesia'}
# {'_id': '111697102184848', 'name': '[Banyuwangi, Jawa Timur]'}
# {'_id': '111697102184848', 'name': '[Banyuwangi, Jawa Timur]'}
# {'_id': '113550041989181', 'name': 'Pekanbaru'}
# {'_id': '113550041989181', 'name': 'Pekanbaru'}
# {'_id': '113212158691616', 'name': 'Bontang, Kalimantan Timur, Indonesia'}
# {'_id': '113212158691616', 'name': '[Bontang, Kalimantan Timur]'}
# {'_id': '113212158691616', 'name': '[Bontang]'}
# {'_id': '113212158691616', 'name': '[Bontang]'}
# {'_id': '103729219665367', 'name': 'Yangon'}
# {'_id': '103729219665367', 'name': 'Yangon'}
# {'_id': '113025492042393', 'name': 'Jember, Moyen-Chari, Chad'}
# {'_id': '113025492042393', 'name': 'Jember, Moyen-Chari, Chad'}
# {'_id': '113503308666510', 'name': 'Tôrres, Rio Grande Do Sul, Brazil'}
# {'_id': '113503308666510', 'name': 'Tôrres, Rio Grande Do Sul, Brazil'}
# {'_id': '113054612039566', 'name': 'Makale, Sulawesi Selatan, Indonesia'}
# {'_id': '113054612039566', 'name': '[Makale, Sulawesi Selatan]'}
# {'_id': '113054612039566', 'name': '[Makale, Sulawesi Selatan]'}
# {'_id': '104270516279522', 'name': 'Tinh Pleiku, Gia Lai, Vietnam'}
# {'_id': '104270516279522', 'name': '[Tinh Pleiku, Gia Lai]'}
# {'_id': '104270516279522', 'name': '[Tinh Pleiku]'}
# {'_id': '104270516279522', 'name': '[Tinh Pleiku]'}
# {'_id': '104929909543246', 'name': 'Phát Diệm, Ninh Bình, Vietnam'}
# {'_id': '104929909543246', 'name': '[Phát Diệm, Ninh Bình]'}
# {'_id': '104929909543246', 'name': '[Phát Diệm, Ninh Bình]'}
# {'_id': '110634518965327', 'name': 'Cua Lo'}
# {'_id': '110634518965327', 'name': 'Cua Lo'}
# {'_id': '114952118516947', 'name': 'San Francisco, California'}
# {'_id': '114952118516947', 'name': '[San Francisco]'}
# {'_id': '114952118516947', 'name': '[San Francisco]'}
# {'_id': '106512056049188', 'name': 'Fox River, Quebec'}
# {'_id': '106512056049188', 'name': 'Fox River, Quebec'}
# {'_id': '103127986394657', 'name': 'Ba Ria'}
# {'_id': '103127986394657', 'name': 'Ba Ria'}
# {'_id': '106085662763201', 'name': 'Lai Vung'}
# {'_id': '106085662763201', 'name': 'Lai Vung'}
# {'_id': '110252925659414', 'name': 'Củ Chi, Hồ Chí Minh, Vietnam'}
# {'_id': '110252925659414', 'name': '[Củ Chi, Hồ Chí Minh]'}
# {'_id': '110252925659414', 'name': '[Củ Chi]'}
# {'_id': '110252925659414', 'name': '[Củ Chi]'}
# {'_id': '102146663160831', 'name': 'Brisbane, Queensland, Australia'}
# {'_id': '102146663160831', 'name': '[Brisbane, Queensland]'}
# {'_id': '102146663160831', 'name': '[Brisbane, Queensland]'}
# {'_id': '110904208934544', 'name': 'Thanh Chuong'}
# {'_id': '110904208934544', 'name': 'Thanh Chuong'}
# {'_id': '111534135535360', 'name': 'Trung Hòa, Đắc Lắk, Vietnam'}
# {'_id': '111534135535360', 'name': '[Trung Hòa, Đắc Lắk]'}
# {'_id': '111534135535360', 'name': '[Trung Hòa]'}
# {'_id': '111534135535360', 'name': '[Trung Hòa]'}
# {'_id': '112870365390628', 'name': 'Palompon, Leyte'}
# {'_id': '112870365390628', 'name': 'Palompon, Leyte'}
# {'_id': '106183376079292', 'name': 'Johor Bahru'}
# {'_id': '106183376079292', 'name': 'Johor Bahru'}
# {'_id': '105479276152349', 'name': 'Lai Chau'}
# {'_id': '105479276152349', 'name': 'Lai Chau'}
# {'_id': '106183886087178', 'name': 'Riyadh, Saudi Arabia'}
# {'_id': '106183886087178', 'name': '[Riyadh]'}
# {'_id': '106183886087178', 'name': '[Riyadh]'}
# {'_id': '109051552455804', 'name': 'Laokai, Lào Cai, Vietnam'}
# {'_id': '109051552455804', 'name': '[Laokai, Lào Cai]'}
# {'_id': '109051552455804', 'name': '[Laokai, Lào Cai]'}
# {'_id': '115972681750561', 'name': 'Cam Pha'}
# {'_id': '115972681750561', 'name': 'Cam Pha'}
# {'_id': '114760591874597', 'name': 'Saltillo, Mexico'}
# {'_id': '114760591874597', 'name': 'Saltillo, Mexico'}
# {'_id': '109955815700240', 'name': 'Cái Bè'}
# {'_id': '109955815700240', 'name': 'Cái Bè'}
# {'_id': '111919858834359', 'name': 'Khartoum, Sudan'}
# {'_id': '111919858834359', 'name': 'Khartoum, Sudan'}
# {'_id': '107755245920605', 'name': 'Bondowoso'}
# {'_id': '107755245920605', 'name': 'Bondowoso'}
# {'_id': '110191339006945', 'name': 'Gia Lai, Gia Lai, Vietnam'}
# {'_id': '110191339006945', 'name': '[Gia Lai, Gia Lai]'}
# {'_id': '110191339006945', 'name': '[Gia Lai]'}
# {'_id': '110191339006945', 'name': '[Gia Lai]'}
# {'_id': '104990316204822', 'name': 'Vĩnh Bình (1), Tiền Giang, Vietnam'}
# {'_id': '104990316204822', 'name': '[Vĩnh Bình (1), Tiền Giang]'}
# {'_id': '104990316204822', 'name': '[Vĩnh Bình (1)]'}
# {'_id': '104990316204822', 'name': '[Vĩnh Bình (1)]'}
# {'_id': '107934015907468', 'name': 'Surabaya, Indonesia'}
# {'_id': '107934015907468', 'name': '[Surabaya]'}
# {'_id': '107934015907468', 'name': '[Surabaya]'}
# {'_id': '106994109330991', 'name': 'Paso De Pache, Canelones, Uruguay'}
# {'_id': '106994109330991', 'name': 'Paso De Pache, Canelones, Uruguay'}
# {'_id': '113240368686567', 'name': 'Elk Grove, California'}
# {'_id': '113240368686567', 'name': '[Elk Grove]'}
# {'_id': '113240368686567', 'name': '[Elk Grove]'}
# {'_id': '104296149610038', 'name': 'Ha Coi, Quảng Ninh, Vietnam'}
# {'_id': '104296149610038', 'name': '[Ha Coi, Quảng Ninh]'}
# {'_id': '104296149610038', 'name': '[Ha Coi]'}
# {'_id': '104296149610038', 'name': '[Ha Coi]'}
# {'_id': '107862585903310', 'name': 'Son Tay'}
# {'_id': '107862585903310', 'name': 'Son Tay'}
# {'_id': '109185362443124', 'name': 'Tarakan, Kalimantan Timur, Indonesia'}
# {'_id': '109185362443124', 'name': '[Tarakan, Kalimantan Timur]'}
# {'_id': '109185362443124', 'name': '[Tarakan]'}
# {'_id': '109185362443124', 'name': '[Tarakan]'}
# {'_id': '115334175145414', 'name': 'Soc Trang'}
# {'_id': '115334175145414', 'name': 'Soc Trang'}
# {'_id': '115334175145414', 'name': 'Soc Trang'}
# {'_id': '115957261747615', 'name': 'Tuy Phong'}
# {'_id': '115957261747615', 'name': 'Tuy Phong'}
# {'_id': '191842347498648', 'name': 'Esashi-gun, Hokkaido, Japan'}
# {'_id': '191842347498648', 'name': 'Esashi-gun, Hokkaido, Japan'}
# {'_id': '115217241824342', 'name': 'Hsinchu, Taiwan'}
# {'_id': '115217241824342', 'name': '[Hsinchu]'}
# {'_id': '115217241824342', 'name': '[Hsinchu]'}
# {'_id': '104668179572393', 'name': 'Haiphong, Hải Phòng, Vietnam'}
# {'_id': '104668179572393', 'name': '[Haiphong, Hải Phòng]'}
# {'_id': '104668179572393', 'name': '[Haiphong]'}
# {'_id': '104668179572393', 'name': '[Haiphong]'}
# {'_id': '104029876300800', 'name': 'Roanoke, Alabama'}
# {'_id': '104029876300800', 'name': 'Roanoke, Alabama'}
# {'_id': '109657585724873', 'name': 'Lai Cách, Hai Hung, Vietnam'}
# {'_id': '109657585724873', 'name': '[Lai Cách, Hai Hung]'}
# {'_id': '109657585724873', 'name': '[Lai Cách, Hai Hung]'}
# {'_id': '102795059756958', 'name': 'Gold Coast, Queensland'}
# {'_id': '102795059756958', 'name': 'Gold Coast, Queensland'}
# {'_id': '102795059756958', 'name': 'Gold Coast, Queensland'}
# {'_id': '102795059756958', 'name': '[Gold Coast]'}
# {'_id': '102795059756958', 'name': '[Gold Coast]'}
# {'_id': '106986596008260', 'name': 'Katum, Tây Ninh, Vietnam'}
# {'_id': '106986596008260', 'name': '[Katum, Tây Ninh]'}
# {'_id': '106986596008260', 'name': '[Katum]'}
# {'_id': '106986596008260', 'name': '[Katum]'}
# {'_id': '110643562296368', 'name': 'Busan, South Korea'}
# {'_id': '110643562296368', 'name': 'Busan, South Korea'}
# {'_id': '113112842048427', 'name': 'Glenmore Park, New South Wales, Australia'}
# {'_id': '113112842048427', 'name': '[Glenmore Park, New South Wales]'}
# {'_id': '113112842048427', 'name': '[Glenmore Park, New South Wales]'}
# {'_id': '112371458788866', 'name': 'Nhon Trach'}
# {'_id': '112371458788866', 'name': 'Nhon Trach'}
# {'_id': '104305192942601', 'name': 'Buôn Krông Bông, Đắc Lắk, Vietnam'}
# {'_id': '104305192942601', 'name': '[Buôn Krông Bông, Đắc Lắk]'}
# {'_id': '104305192942601', 'name': '[Buôn Krông Bông]'}
# {'_id': '104305192942601', 'name': '[Buôn Krông Bông]'}
# {'_id': '176308355722327', 'name': 'Marcelândia'}
# {'_id': '176308355722327', 'name': 'Marcelândia'}
# {'_id': '109740452377835', 'name': 'Bac Lieu'}
# {'_id': '109740452377835', 'name': 'Bac Lieu'}
# {'_id': '111649395528170', 'name': 'Kharkov, Ukraine'}
# {'_id': '111649395528170', 'name': 'Kharkov, Ukraine'}
# {'_id': '116284465053371', 'name': 'Jombang, Jawa Timur, Indonesia'}
# {'_id': '116284465053371', 'name': '[Jombang, Jawa Timur]'}
# {'_id': '116284465053371', 'name': '[Jombang]'}
# {'_id': '116284465053371', 'name': '[Jombang]'}
# {'_id': '115085015172389', 'name': 'Moscow, Russia'}
# {'_id': '115085015172389', 'name': 'Moscow, Russia'}
# {'_id': '108206999203128', 'name': 'Osaka'}
# {'_id': '108206999203128', 'name': 'Osaka'}
# {'_id': '107831159249946', 'name': 'Phúc Yên'}
# {'_id': '107831159249946', 'name': 'Phúc Yên'}
# {'_id': '113659978648324', 'name': 'Nhu Quynh, Hai Hung, Vietnam'}
# {'_id': '113659978648324', 'name': '[Nhu Quynh, Hai Hung]'}
# {'_id': '113659978648324', 'name': '[Nhu Quynh]'}
# {'_id': '113659978648324', 'name': '[Nhu Quynh]'}
# {'_id': '114878888524752', 'name': 'Hồng Ngự'}
# {'_id': '114878888524752', 'name': 'Hồng Ngự'}
# {'_id': '113028395375044', 'name': 'Binh Dinh, Nghia Binh, Vietnam'}
# {'_id': '113028395375044', 'name': '[Binh Dinh, Nghia Binh]'}
# {'_id': '113028395375044', 'name': '[Binh Dinh, Nghia Binh]'}
# {'_id': '114847425195466', 'name': 'Phu Cuong, Song Be, Vietnam'}
# {'_id': '114847425195466', 'name': '[Phu Cuong, Song Be]'}
# {'_id': '114847425195466', 'name': '[Phu Cuong]'}
# {'_id': '114847425195466', 'name': '[Phu Cuong]'}
# {'_id': '108538305837823', 'name': 'California City, California'}
# {'_id': '108538305837823', 'name': '[California City]'}
# {'_id': '108538305837823', 'name': '[California City]'}
# {'_id': '107983305896554', 'name': 'Móng Cái'}
# {'_id': '107983305896554', 'name': 'Móng Cái'}
# {'_id': '109252215761161', 'name': 'Yên Bái'}
# {'_id': '109252215761161', 'name': 'Yên Bái'}
# {'_id': '107983435897193', 'name': 'Fresno, California'}
# {'_id': '107983435897193', 'name': '[Fresno]'}
# {'_id': '107983435897193', 'name': '[Fresno]'}
# {'_id': '196106953772010', 'name': 'Long Thành'}
# {'_id': '115486911798138', 'name': 'Almaty, Kazakhstan'}
# {'_id': '115486911798138', 'name': '[Almaty]'}
# {'_id': '115486911798138', 'name': '[Almaty]'}
# {'_id': '103781489660403', 'name': 'Nganjuk'}
# {'_id': '103781489660403', 'name': 'Nganjuk'}
# {'_id': '105479186151832', 'name': 'Coffs Harbour, New South Wales'}
# {'_id': '105479186151832', 'name': 'Coffs Harbour, New South Wales'}
# {'_id': '105479186151832', 'name': 'Coffs Harbour, New South Wales'}
# {'_id': '105479186151832', 'name': '[Coffs Harbour]'}
# {'_id': '105479186151832', 'name': '[Coffs Harbour]'}
# {'_id': '110468562315381', 'name': 'Can Giuoc'}
# {'_id': '110468562315381', 'name': 'Can Giuoc'}
# {'_id': '108556445834614', 'name': 'Miskovice'}
# {'_id': '108556445834614', 'name': 'Miskovice'}
# {'_id': '106194396082939', 'name': 'Kuching, Malaysia'}
# {'_id': '106194396082939', 'name': '[Kuching]'}
# {'_id': '106194396082939', 'name': '[Kuching]'}
# {'_id': '104099259626424', 'name': 'Mascara, Algeria'}
# {'_id': '104099259626424', 'name': '[Mascara]'}
# {'_id': '104099259626424', 'name': '[Mascara]'}
# {'_id': '113634448649072', 'name': 'Sài Gòn, Sóc Trăng, Vietnam'}
# {'_id': '113634448649072', 'name': '[Sài Gòn, Sóc Trăng]'}
# {'_id': '113634448649072', 'name': '[Sài Gòn]'}
# {'_id': '113634448649072', 'name': '[Sài Gòn]'}
# {'_id': '115970731750761', 'name': 'Adelaide, South Australia'}
# {'_id': '115970731750761', 'name': 'Adelaide, South Australia'}
# {'_id': '103020529734416', 'name': 'Milton Keynes'}
# {'_id': '103020529734416', 'name': 'Milton Keynes'}
# {'_id': '108576292507505', 'name': 'Dau Tieng'}
# {'_id': '108576292507505', 'name': 'Dau Tieng'}
# {'_id': '111984192160228', 'name': 'Xuong Cua May Dak Song, Đắc Lắk, Vietnam'}
# {'_id': '111984192160228', 'name': '[Xuong Cua May Dak Song, Đắc Lắk]'}
# {'_id': '111984192160228', 'name': '[Xuong Cua May Dak Song]'}
# {'_id': '111984192160228', 'name': '[Xuong Cua May Dak Song]'}
# {'_id': '113146088698173', 'name': 'Quang Ninh, Binh Tri Thien, Vietnam'}
# {'_id': '113146088698173', 'name': '[Quang Ninh, Binh Tri Thien]'}
# {'_id': '113146088698173', 'name': '[Quang Ninh, Binh Tri Thien]'}
# {'_id': '100241520017202', 'name': 'Huyện Thạnh Trị, Bạc Liêu, Vietnam'}
# {'_id': '100241520017202', 'name': '[Huyện Thạnh Trị, Bạc Liêu]'}
# {'_id': '100241520017202', 'name': '[Huyện Thạnh Trị, Bạc Liêu]'}
# {'_id': '106530866047287', 'name': 'Phu Tho, Phú Thọ, Vietnam'}
# {'_id': '106530866047287', 'name': '[Phu Tho, Phú Thọ]'}
# {'_id': '106530866047287', 'name': '[Phu Tho, Phú Thọ]'}
# {'_id': '112089428815888', 'name': 'Xuân Lộc, Ðồng Nai, Vietnam'}
# {'_id': '112089428815888', 'name': '[Xuân Lộc, Ðồng Nai]'}
# {'_id': '112089428815888', 'name': '[Xuân Lộc, Ðồng Nai]'}
# {'_id': '110228155672622', 'name': 'Thanh Khê'}
# {'_id': '110228155672622', 'name': 'Thanh Khê'}
# {'_id': '104307946276737', 'name': 'Cap-Saint-Jacques, Bà Rịa-Vũng Tàu, Vietnam'}
# {'_id': '104307946276737', 'name': '[Cap-Saint-Jacques, Bà Rịa-Vũng Tàu]'}
# {'_id': '104307946276737', 'name': '[Cap-Saint-Jacques, Bà Rịa-Vũng Tàu]'}
# {'_id': '106920359339465', 'name': 'An Duong, Hải Phòng, Vietnam'}
# {'_id': '106920359339465', 'name': '[An Duong, Hải Phòng]'}
# {'_id': '106920359339465', 'name': '[An Duong]'}
# {'_id': '106920359339465', 'name': '[An Duong]'}
# {'_id': '112233415455614', 'name': 'New Rochelle, New York'}
# {'_id': '112233415455614', 'name': '[New Rochelle]'}
# {'_id': '112233415455614', 'name': '[New Rochelle]'}
# {'_id': '109280919098351', 'name': 'Szerencs'}
# {'_id': '109280919098351', 'name': 'Szerencs'}
# {'_id': '108074502553840', 'name': 'Samarinda'}
# {'_id': '108074502553840', 'name': 'Samarinda'}
# {'_id': '111047295591403', 'name': 'Mount Keira, New South Wales, Australia'}
# {'_id': '108017232565792', 'name': 'Quy Nhon'}
# {'_id': '108017232565792', 'name': 'Quy Nhon'}
# {'_id': '108411835855466', 'name': 'Cban, Plzeňský Kraj, Czech Republic'}
# {'_id': '108411835855466', 'name': '[Cban, Plzeňský Kraj]'}
# {'_id': '108411835855466', 'name': '[Cban, Plzeňský Kraj]'}
# {'_id': '113061118710659', 'name': 'Xa Vung Tau, Bà Rịa-Vũng Tàu, Vietnam'}
# {'_id': '113061118710659', 'name': '[Xa Vung Tau, Bà Rịa-Vũng Tàu]'}
# {'_id': '113061118710659', 'name': '[Xa Vung Tau]'}
# {'_id': '113061118710659', 'name': '[Xa Vung Tau]'}
# {'_id': '108061005893923', 'name': 'Peshawar, Pakistan'}
# {'_id': '108061005893923', 'name': 'Peshawar, Pakistan'}
# {'_id': '104347542939498', 'name': 'Khê Mao, Quảng Ninh, Vietnam'}
# {'_id': '104347542939498', 'name': '[Khê Mao, Quảng Ninh]'}
# {'_id': '104347542939498', 'name': '[Khê Mao]'}
# {'_id': '104347542939498', 'name': '[Khê Mao]'}
# {'_id': '111165112241092', 'name': 'Vienna, Austria'}
# {'_id': '111165112241092', 'name': 'Vienna, Austria'}
# {'_id': '108458742510900', 'name': 'Vietri, Phú Thọ, Vietnam'}
# {'_id': '108458742510900', 'name': '[Vietri, Phú Thọ]'}
# {'_id': '108458742510900', 'name': '[Vietri]'}
# {'_id': '108458742510900', 'name': '[Vietri]'}
# {'_id': '109097349123993', 'name': 'Thac Tri An, Vietnam'}
# {'_id': '109097349123993', 'name': '[Thac Tri An]'}
# {'_id': '109097349123993', 'name': '[Thac Tri An]'}
# {'_id': '111262742228544', 'name': 'Kidima'}
# {'_id': '111262742228544', 'name': 'Kidima'}
# {'_id': '105785882794729', 'name': 'Bát Xát'}
# {'_id': '105785882794729', 'name': 'Bát Xát'}
# {'_id': '112085882141845', 'name': 'Rangamati'}
# {'_id': '112085882141845', 'name': 'Rangamati'}
# {'_id': '110730292284790', 'name': 'Beijing, China'}
# {'_id': '110730292284790', 'name': '[Beijing]'}
# {'_id': '110730292284790', 'name': '[Beijing]'}
# {'_id': '105540216147364', 'name': 'Phoenix, Arizona'}
# {'_id': '105540216147364', 'name': 'Phoenix, Arizona'}
# {'_id': '110419212320033', 'name': 'Indianapolis, Indiana'}
# {'_id': '110419212320033', 'name': 'Indianapolis, Indiana'}
# {'_id': '114849435197846', 'name': 'Bình Liêu'}
# {'_id': '114849435197846', 'name': 'Bình Liêu'}
# {'_id': '108135415874412', 'name': 'Tân Châu'}
# {'_id': '108135415874412', 'name': 'Tân Châu'}
# {'_id': '110603252295205', 'name': 'Loc Ninh'}
# {'_id': '110603252295205', 'name': 'Loc Ninh'}
# {'_id': '109192492441462', 'name': 'Hương Cẩm Thủy, Thanh Hóa, Vietnam'}
# {'_id': '109192492441462', 'name': '[Hương Cẩm Thủy, Thanh Hóa]'}
# {'_id': '109192492441462', 'name': '[Hương Cẩm Thủy]'}
# {'_id': '109192492441462', 'name': '[Hương Cẩm Thủy]'}
# {'_id': '105830519457917', 'name': 'Tân Thành'}
# {'_id': '105830519457917', 'name': 'Tân Thành'}
# {'_id': '105641672801586', 'name': 'Bac Kan'}
# {'_id': '105641672801586', 'name': 'Bac Kan'}
# {'_id': '109433122412192', 'name': 'Dubai, Uttar Pradesh, India'}
# {'_id': '109542952404733', 'name': 'Sirajganj'}
# {'_id': '109542952404733', 'name': 'Sirajganj'}
# {'_id': '110468792308192', 'name': 'Sông Cầu'}
# {'_id': '110468792308192', 'name': 'Sông Cầu'}
# {'_id': '107474775954811', 'name': 'Duc Noi, Ha Noi, Vietnam'}
# {'_id': '107474775954811', 'name': '[Duc Noi, Ha Noi]'}
# {'_id': '107474775954811', 'name': '[Duc Noi]'}
# {'_id': '107474775954811', 'name': '[Duc Noi]'}
# {'_id': '111373282214381', 'name': 'Tiên Yên'}
# {'_id': '111373282214381', 'name': 'Tiên Yên'}
# {'_id': '109230862430439', 'name': 'Hòa Bình, Bạc Liêu, Vietnam'}
# {'_id': '109230862430439', 'name': '[Hòa Bình, Bạc Liêu]'}
# {'_id': '109230862430439', 'name': '[Hòa Bình]'}
# {'_id': '109230862430439', 'name': '[Hòa Bình]'}
# {'_id': '109493952401635', 'name': 'Fernandópolis'}
# {'_id': '109493952401635', 'name': 'Fernandópolis'}
# {'_id': '107072045990592', 'name': 'Huong Canh, Vinh Phu, Vietnam'}
# {'_id': '107072045990592', 'name': '[Huong Canh, Vinh Phu]'}
# {'_id': '107072045990592', 'name': '[Huong Canh]'}
# {'_id': '107072045990592', 'name': '[Huong Canh]'}
# {'_id': '114949715189041', 'name': 'Tuy Phuoc'}
# {'_id': '114949715189041', 'name': 'Tuy Phuoc'}
# {'_id': '114183551925573', 'name': 'Thái Bình'}
# ...
# {'_id': '114897241858995', 'name': '[Algeciras]'}
# {'_id': '104318842941952', 'name': 'Buon Trap, Đắc Lắk, Vietnam'}
# {'_id': '104318842941952', 'name': '[Buon Trap, Đắc Lắk]'}
# {'_id': '104318842941952', 'name': '[Buon Trap]'}
# {'_id': '104318842941952', 'name': '[Buon Trap]'}
# {'_id': '108309132530933', 'name': 'Sampit'}
# {'_id': '108309132530933', 'name': 'Sampit'}
# {'_id': '111439848877729', 'name': 'Ban Nhang, Lạng Sơn, Vietnam'}
# {'_id': '111439848877729', 'name': '[Ban Nhang, Lạng Sơn]'}
# {'_id': '111439848877729', 'name': '[Ban Nhang, Lạng Sơn]'}
# {'_id': '111439848877729', 'name': '[Ban Nhang, Lạng Sơn]'}
# {'_id': '111439848877729', 'name': '[Ban Nhang]'}
# {'_id': '111439848877729', 'name': '[Ban Nhang]'}
# {'_id': '112943832054341', 'name': 'Ithaca, New York'}
# {'_id': '112943832054341', 'name': '[Ithaca]'}
# {'_id': '112943832054341', 'name': '[Ithaca]'}
# {'_id': '102194039822307', 'name': 'Bogotá, Colombia'}
# {'_id': '102194039822307', 'name': 'Bogotá, Colombia'}
# {'_id': '102194039822307', 'name': 'Bogotá, Colombia'}
# {'_id': '102194039822307', 'name': '[Bogotá]'}
# {'_id': '102194039822307', 'name': '[Bogotá]'}
# {'_id': '106057006099965', 'name': 'Phu Luong'}
# {'_id': '106057006099965', 'name': 'Phu Luong'}
# {'_id': '109260602433140', 'name': 'Columbus, Georgia'}
# {'_id': '109260602433140', 'name': '[Columbus]'}
# {'_id': '109260602433140', 'name': '[Columbus]'}
# {'_id': '109566625736089', 'name': 'Cirebon'}
# {'_id': '109566625736089', 'name': 'Cirebon'}
# {'_id': '110581725635488', 'name': 'Hanoi, Southern Highlands, Papua New Guinea'}
# {'_id': '110581725635488', 'name': 'Hanoi, Southern Highlands, Papua New Guinea'}
# {'_id': '108454162512960', 'name': 'Lopburi'}
# {'_id': '108454162512960', 'name': 'Lopburi'}
# {'_id': '108454162512960', 'name': 'Lopburi'}
# {'_id': '115353315143936', 'name': 'Rome, Italy'}
# {'_id': '115353315143936', 'name': '[Rome]'}
# {'_id': '115353315143936', 'name': '[Rome]'}
# {'_id': '113150042030256', 'name': 'Paloe, Sulawesi Tengah, Indonesia'}
# {'_id': '113150042030256', 'name': '[Paloe, Sulawesi Tengah]'}
# {'_id': '113150042030256', 'name': '[Paloe]'}
# {'_id': '113150042030256', 'name': '[Paloe]'}
# {'_id': '105539406146801', 'name': 'Gilford, New Hampshire'}
# {'_id': '105539406146801', 'name': '[Gilford]'}
# {'_id': '105539406146801', 'name': '[Gilford]'}
# {'_id': '114639405215273', 'name': 'St. Louis'}
# {'_id': '114639405215273', 'name': 'St. Louis'}
# {'_id': '110173019000624', 'name': 'Pinrang, Sulawesi Selatan, Indonesia'}
# {'_id': '110173019000624', 'name': '[Pinrang, Sulawesi Selatan]'}
# {'_id': '110173019000624', 'name': '[Pinrang]'}
# {'_id': '110173019000624', 'name': '[Pinrang]'}
# {'_id': '109490939078021', 'name': 'Highland, California'}
# {'_id': '109490939078021', 'name': '[Highland]'}
# {'_id': '109490939078021', 'name': '[Highland]'}
# {'_id': '111053908917446', 'name': 'Xã Bình Long, Vietnam'}
# {'_id': '111053908917446', 'name': '[Xã Bình Long]'}
# {'_id': '111053908917446', 'name': '[Xã Bình Long]'}
# {'_id': '106341192737428', 'name': 'Belém, Brazil'}
# {'_id': '106341192737428', 'name': '[Belém]'}
# {'_id': '106341192737428', 'name': '[Belém]'}
# {'_id': '100246103350680', 'name': 'Ijero Ekiti, Ekiti, Nigeria'}
# {'_id': '100246103350680', 'name': '[Ijero Ekiti, Ekiti]'}
# {'_id': '100246103350680', 'name': '[Ijero Ekiti, Ekiti]'}
# {'_id': '104347702938371', 'name': 'Pasir Gudang, Johor, Malaysia'}
# {'_id': '104347702938371', 'name': '[Pasir Gudang, Johor]'}
# {'_id': '104347702938371', 'name': '[Pasir Gudang, Johor]'}
# {'_id': '110589025635590', 'name': 'Prague, Czech Republic'}
# {'_id': '110589025635590', 'name': '[Prague]'}
# {'_id': '110589025635590', 'name': '[Prague]'}
# {'_id': '106329652732066', 'name': 'Roxas, Isabela'}
# {'_id': '106329652732066', 'name': 'Roxas, Isabela'}
# {'_id': '104021026300705', 'name': 'Tampines New Town'}
# {'_id': '104021026300705', 'name': 'Tampines New Town'}
# {'_id': '112846768729872', 'name': 'Lawrence, Massachusetts'}
# {'_id': '112846768729872', 'name': '[Lawrence]'}
# {'_id': '112846768729872', 'name': '[Lawrence]'}
# {'_id': '108047329223312', 'name': 'Harwich, Massachusetts'}
# {'_id': '108047329223312', 'name': '[Harwich]'}
# {'_id': '108047329223312', 'name': '[Harwich]'}
# {'_id': '107430505960402', 'name': 'Tu Son, Hi Bac, Vietnam'}
# {'_id': '107430505960402', 'name': '[Tu Son, Hi Bac]'}
# {'_id': '107430505960402', 'name': '[Tu Son]'}
# {'_id': '107430505960402', 'name': '[Tu Son]'}
# {'_id': '104634099575488', 'name': 'Vientane, Vientiane, Laos'}
# {'_id': '104634099575488', 'name': '[Vientane, Vientiane]'}
# {'_id': '104634099575488', 'name': '[Vientane]'}
# {'_id': '104634099575488', 'name': '[Vientane]'}
# {'_id': '108485095839186', 'name': 'Siedlce'}
# {'_id': '108485095839186', 'name': 'Siedlce'}
# {'_id': '111934802166307', 'name': 'Las Condes, Chile'}
# {'_id': '111934802166307', 'name': 'Las Condes, Chile'}
# {'_id': '106069706098228', 'name': 'Brantford, Ontario'}
# {'_id': '106069706098228', 'name': '[Brantford]'}
# {'_id': '106069706098228', 'name': '[Brantford]'}
# {'_id': '109091652452570', 'name': 'Ap Binh Thuan, Minh Hai, Vietnam'}
# {'_id': '109091652452570', 'name': '[Ap Binh Thuan, Minh Hai]'}
# {'_id': '109091652452570', 'name': '[Ap Binh Thuan, Minh Hai]'}
# {'_id': '108074279225244', 'name': 'Cam Thuy'}
# {'_id': '108074279225244', 'name': 'Cam Thuy'}
# {'_id': '108872385813004', 'name': 'Ban Dak, Đắc Lắk, Vietnam'}
# {'_id': '108872385813004', 'name': '[Ban Dak, Đắc Lắk]'}
# {'_id': '108872385813004', 'name': '[Ban Dak]'}
# {'_id': '108872385813004', 'name': '[Ban Dak]'}
# {'_id': '108093595891301', 'name': 'Makilala'}
# {'_id': '108093595891301', 'name': 'Makilala'}
# {'_id': '106274672743031', 'name': 'Quang Trach'}
# {'_id': '106274672743031', 'name': 'Quang Trach'}
# {'_id': '104934406209020', 'name': 'Ha Lam, Quảng Ninh, Vietnam'}
# {'_id': '104934406209020', 'name': '[Ha Lam, Quảng Ninh]'}
# {'_id': '104934406209020', 'name': '[Ha Lam]'}
# {'_id': '104934406209020', 'name': '[Ha Lam]'}
# {'_id': '108251189197758', 'name': 'West Palm Beach, Florida'}
# {'_id': '108251189197758', 'name': '[West Palm Beach]'}
# {'_id': '108251189197758', 'name': '[West Palm Beach]'}
# {'_id': '105517159482412', 'name': 'Salatiga'}
# {'_id': '105517159482412', 'name': 'Salatiga'}
# {'_id': '107002132664472', 'name': 'Cao Bang, Binh Tri Thien, Vietnam'}
# {'_id': '107002132664472', 'name': '[Cao Bang, Binh Tri Thien]'}
# {'_id': '107002132664472', 'name': '[Cao Bang]'}
# {'_id': '107002132664472', 'name': '[Cao Bang]'}
# {'_id': '101896829852427', 'name': 'Aix-en-Provence, France'}
# {'_id': '101896829852427', 'name': '[Aix-en-Provence]'}
# {'_id': '101896829852427', 'name': '[Aix-en-Provence]'}
# {'_id': '115214755159360', 'name': 'Maisons-Alfort, France'}
# {'_id': '115214755159360', 'name': '[Maisons-Alfort]'}
# {'_id': '115214755159360', 'name': '[Maisons-Alfort]'}
# {'_id': '105449159489172', 'name': 'Eden Prairie, Minnesota'}
# {'_id': '105449159489172', 'name': '[Eden Prairie]'}
# {'_id': '105449159489172', 'name': '[Eden Prairie]'}
# {'_id': '144870998915178', 'name': 'Seongnam'}
# {'_id': '144870998915178', 'name': 'Seongnam'}
# {'_id': '111367478886197', 'name': 'Phnum Pénh, Phnum Penh, Cambodia'}
# {'_id': '111367478886197', 'name': 'Phnum Pénh, Phnum Penh, Cambodia'}
# {'_id': '116308828384209', 'name': 'Oton, Iloilo, Philippines'}
# {'_id': '116308828384209', 'name': '[Oton, Iloilo]'}
# {'_id': '116308828384209', 'name': '[Oton, Iloilo]'}
# {'_id': '114600441890814', 'name': 'Shibuya, Tokyo'}
# {'_id': '114600441890814', 'name': '[Shibuya]'}
# {'_id': '114600441890814', 'name': '[Shibuya]'}
# {'_id': '113989751947886', 'name': 'Hồ Xá, Quảng Trị, Vietnam'}
# {'_id': '113989751947886', 'name': '[Hồ Xá, Quảng Trị]'}
# {'_id': '113989751947886', 'name': '[Hồ Xá]'}
# {'_id': '113989751947886', 'name': '[Hồ Xá]'}
# {'_id': '104002292969382', 'name': 'Santander, Cantabria'}
# {'_id': '104002292969382', 'name': 'Santander, Cantabria'}
# {'_id': '106448376054629', 'name': 'Kon Tum (2), Gia Lai-Cong Tum, Vietnam'}
# {'_id': '106448376054629', 'name': '[Kon Tum (2), Gia Lai-Cong Tum]'}
# {'_id': '106448376054629', 'name': '[Kon Tum (2), Gia Lai-Cong Tum]'}
# {'_id': '113374008677348', 'name': 'Mamasa, Sulawesi Selatan, Indonesia'}
# {'_id': '113374008677348', 'name': '[Mamasa, Sulawesi Selatan]'}
# {'_id': '113374008677348', 'name': '[Mamasa]'}
# {'_id': '113374008677348', 'name': '[Mamasa]'}
# {'_id': '116316511713006', 'name': 'Kangnamni, Hwanghae-Bukto, Korea'}
# {'_id': '113306745351656', 'name': 'Phú Túc, Gia Lai, Vietnam'}
# {'_id': '113306745351656', 'name': '[Phú Túc, Gia Lai]'}
# {'_id': '105396882827337', 'name': 'Pasadena, California'}
# {'_id': '105396882827337', 'name': '[Pasadena]'}
# {'_id': '105396882827337', 'name': '[Pasadena]'}
# {'_id': '104005829635705', 'name': 'Gothenburg'}
# {'_id': '104005829635705', 'name': 'Gothenburg'}
# {'_id': '112815882070381', 'name': 'Sông-Bé, Song Be, Vietnam'}
# {'_id': '112815882070381', 'name': '[Sông-Bé, Song Be]'}
# {'_id': '112815882070381', 'name': '[Sông-Bé]'}
# {'_id': '112815882070381', 'name': '[Sông-Bé]'}
# {'_id': '109593732392630', 'name': 'Hyderabad, Sindh'}
# {'_id': '109593732392630', 'name': 'Hyderabad, Sindh'}
# {'_id': '104023459634857', 'name': 'Dayton, Ohio'}
# {'_id': '104023459634857', 'name': '[Dayton]'}
# {'_id': '104023459634857', 'name': '[Dayton]'}
# {'_id': '109331452427743', 'name': 'Hà �Ông, Hà Tây, Vietnam'}
# {'_id': '109331452427743', 'name': '[Hà �Ông, Hà Tây]'}
# {'_id': '109331452427743', 'name': '[Hà �Ông, Hà Tây]'}
# {'_id': '108546129175566', 'name': 'Laurel, Puntarenas, Costa Rica'}
# {'_id': '108546129175566', 'name': '[Laurel, Puntarenas]'}
# {'_id': '108546129175566', 'name': '[Laurel, Puntarenas]'}
# {'_id': '115785835100914', 'name': 'Shubra al Khaymah'}
# {'_id': '115785835100914', 'name': 'Shubra al Khaymah'}
# {'_id': '108000485887597', 'name': 'Duluth, Minnesota'}
# {'_id': '108000485887597', 'name': '[Duluth]'}
# {'_id': '108000485887597', 'name': '[Duluth]'}
# {'_id': '111109305584944', 'name': 'Toy Hoa, Phú Yên, Vietnam'}
# {'_id': '111109305584944', 'name': '[Toy Hoa, Phú Yên]'}
# {'_id': '111109305584944', 'name': '[Toy Hoa]'}
# {'_id': '111109305584944', 'name': '[Toy Hoa]'}
# {'_id': '110532925633526', 'name': 'Sorocaba, Brazil'}
# {'_id': '110532925633526', 'name': '[Sorocaba]'}
# {'_id': '110532925633526', 'name': '[Sorocaba]'}
# {'_id': '102227949851328', 'name': 'Higashiomi-shi, Shiga, Japan'}
# {'_id': '102227949851328', 'name': '[Higashiomi-shi, Shiga]'}
# {'_id': '102227949851328', 'name': '[Higashiomi-shi, Shiga]'}
# {'_id': '106297799408973', 'name': 'Oldenburg, Germany'}
# {'_id': '106297799408973', 'name': '[Oldenburg]'}
# {'_id': '106297799408973', 'name': '[Oldenburg]'}
# {'_id': '110723928949850', 'name': 'Speyer, Germany'}
# {'_id': '110723928949850', 'name': '[Speyer]'}
# {'_id': '110723928949850', 'name': '[Speyer]'}
# {'_id': '104110689624486', 'name': 'Ellsworth, Maine'}
# {'_id': '104110689624486', 'name': '[Ellsworth]'}
# {'_id': '104110689624486', 'name': '[Ellsworth]'}
# {'_id': '109259949093253', 'name': 'Peachtree City, Georgia'}
# {'_id': '109259949093253', 'name': '[Peachtree City]'}
# {'_id': '109259949093253', 'name': '[Peachtree City]'}
# {'_id': '107213532650378', 'name': 'Hoa Lac, An Giang, Vietnam'}
# {'_id': '107213532650378', 'name': '[Hoa Lac, An Giang]'}
# {'_id': '107213532650378', 'name': '[Hoa Lac]'}
# {'_id': '107213532650378', 'name': '[Hoa Lac]'}
# {'_id': '106152016081829', 'name': 'Bakersfield, California'}
# {'_id': '106152016081829', 'name': '[Bakersfield]'}
# {'_id': '106152016081829', 'name': '[Bakersfield]'}
# {'_id': '110516482301368', 'name': 'Gò Công, Hồ Chí Minh, Vietnam'}
# {'_id': '110516482301368', 'name': '[Gò Công, Hồ Chí Minh]'}
# {'_id': '110516482301368', 'name': '[Gò Công]'}
# {'_id': '110516482301368', 'name': '[Gò Công]'}
# {'_id': '104146379622955', 'name': 'Westminster, California'}
# {'_id': '104146379622955', 'name': '[Westminster]'}
# {'_id': '104146379622955', 'name': '[Westminster]'}
# {'_id': '106487912721749', 'name': 'Chengdu, Sichuan'}
# {'_id': '106487912721749', 'name': 'Chengdu, Sichuan'}
# {'_id': '113791461968297', 'name': 'Vinh, Hi Bac, Vietnam'}
# {'_id': '113791461968297', 'name': '[Vinh, Hi Bac]'}
# {'_id': '113791461968297', 'name': '[Vinh]'}
# {'_id': '113791461968297', 'name': '[Vinh]'}
# {'_id': '113299768681226', 'name': 'Thai, Bac Thai, Vietnam'}
# {'_id': '113299768681226', 'name': '[Thai, Bac Thai]'}
# {'_id': '113299768681226', 'name': '[Thai, Bac Thai]'}
# {'_id': '110440995644871', 'name': 'Tabaco'}
# {'_id': '110440995644871', 'name': 'Tabaco'}
# {'_id': '108056642561514', 'name': 'Giao Thuy'}
# {'_id': '108056642561514', 'name': 'Giao Thuy'}
# {'_id': '104013469634770', 'name': 'Kangar'}
# {'_id': '104013469634770', 'name': 'Kangar'}
# {'_id': '111244132234068', 'name': 'Pulau Pinang'}
# {'_id': '111244132234068', 'name': 'Pulau Pinang'}
# {'_id': '111244132234068', 'name': 'Pulau Pinang'}
# {'_id': '108860122465966', 'name': 'Hanam'}
# {'_id': '108860122465966', 'name': 'Hanam'}
# {'_id': '108860122465966', 'name': 'Hanam'}
# {'_id': '112918012057843', 'name': 'Chiang Kham, Phayao, Thailand'}
# {'_id': '112918012057843', 'name': '[Chiang Kham, Phayao]'}
# {'_id': '112918012057843', 'name': '[Chiang Kham, Phayao]'}
# {'_id': '108169225869823', 'name': 'Tangail'}
# {'_id': '108169225869823', 'name': 'Tangail'}
# {'_id': '112955888721021', 'name': 'Yên Bài, Ha Nam Ninh, Vietnam'}
# {'_id': '112955888721021', 'name': '[Yên Bài, Ha Nam Ninh]'}
# {'_id': '112955888721021', 'name': '[Yên Bài]'}
# {'_id': '112955888721021', 'name': '[Yên Bài]'}
# {'_id': '112589605418710', 'name': 'Cartagena, Colombia'}
# {'_id': '112589605418710', 'name': 'Cartagena, Colombia'}
# {'_id': '112589605418710', 'name': 'Cartagena, Colombia'}
# {'_id': '112589605418710', 'name': '[Cartagena]'}
# {'_id': '112589605418710', 'name': '[Cartagena]'}
# {'_id': '107549705934644', 'name': 'Saou'}
# {'_id': '107549705934644', 'name': 'Saou'}
# {'_id': '110739442284735', 'name': 'Attopeu'}
# {'_id': '110739442284735', 'name': 'Attopeu'}
# {'_id': '113122798699277', 'name': 'Valença, Bahia, Brazil'}
# {'_id': '113122798699277', 'name': '[Valença, Bahia]'}
# {'_id': '113122798699277', 'name': '[Valença]'}
# {'_id': '113122798699277', 'name': '[Valença]'}
# {'_id': '103347953039995', 'name': 'Tiên Quán, Hai Hung, Vietnam'}
# {'_id': '103347953039995', 'name': '[Tiên Quán, Hai Hung]'}
# {'_id': '103347953039995', 'name': '[Tiên Quán]'}
# {'_id': '103347953039995', 'name': '[Tiên Quán]'}
# {'_id': '110409778986744', 'name': 'Port Moresby, Papua New Guinea'}
# {'_id': '110409778986744', 'name': '[Port Moresby]'}
# {'_id': '110409778986744', 'name': '[Port Moresby]'}
# {'_id': '113014728713082', 'name': 'Szentendre'}
# {'_id': '113014728713082', 'name': 'Szentendre'}
# {'_id': '106065976090577', 'name': 'Binghamton, New York'}
# {'_id': '106065976090577', 'name': '[Binghamton]'}
# {'_id': '106065976090577', 'name': '[Binghamton]'}
# {'_id': '111728892178150', 'name': 'Tuyên Hóa'}
# {'_id': '111728892178150', 'name': 'Tuyên Hóa'}
# {'_id': '105764076123853', 'name': 'Nawalapitiya'}
# {'_id': '105764076123853', 'name': 'Nawalapitiya'}
# {'_id': '108328065856235', 'name': 'York'}
# {'_id': '107813172585534', 'name': 'Baku, Azerbaijan'}
# {'_id': '107813172585534', 'name': 'Baku, Azerbaijan'}
# {'_id': '107666599263369', 'name': 'Plymouth'}
# {'_id': '107666599263369', 'name': 'Plymouth'}
# {'_id': '108238772543817', 'name': 'Nga Son'}
# {'_id': '108238772543817', 'name': 'Nga Son'}
# {'_id': '104289536272768', 'name': 'Surin, Thailand'}
# {'_id': '104289536272768', 'name': '[Surin]'}
# {'_id': '104289536272768', 'name': '[Surin]'}
# {'_id': '115396908474341', 'name': 'Vinh Chau'}
# {'_id': '115396908474341', 'name': 'Vinh Chau'}
# {'_id': '115396908474341', 'name': 'Vinh Chau'}
# {'_id': '106373139394499', 'name': 'Port Douglas'}
# {'_id': '106373139394499', 'name': 'Port Douglas'}
# {'_id': '106478449388242', 'name': 'Trieu Phong'}
# {'_id': '106478449388242', 'name': 'Trieu Phong'}
# {'_id': '105585682807310', 'name': 'Acworth, Georgia'}
# {'_id': '105585682807310', 'name': '[Acworth]'}
# {'_id': '105585682807310', 'name': '[Acworth]'}
# {'_id': '112376722107315', 'name': 'Auburn, Maine'}
# {'_id': '112376722107315', 'name': '[Auburn]'}
# {'_id': '112376722107315', 'name': '[Auburn]'}
# 19.91907501220703

# %%
import json
for group in g:
    group = group.toDict()
    group = str(group).replace("{\'", "{\"").replace("\':", "\":")
    group = group.replace("\"\"" , "\"" )
    group = json.loads(group)
    print(json.dumps(group, indent=2, sort_keys=True, ensure_ascii = False))
# Out:
# {
#   "Vietnam": [
#     {
#       "Hanoi": [
#         {
#           "Mai Dich": []
#         },
#         {
#           "Me Tri": []
#         },
#         {
#           "Ha Loi": []
#         },
#         {
#           "Hoai Duc Phu": []
#         },
#         {
#           "Vinh Phuc": []
#         },
#         {
#           "Duc Noi": []
#         },
#         {
#           "Phú Xuyên": []
#         },
#         {
#           "Tay Ho": []
#         },
#         {
#           "Gia Lâm Pho": []
#         },
#         {
#           "Quan Nhan": []
#         },
#         {
#           "Van Dinh": []
#         },
#         {
#           "Hanoi Bac Mai": []
#         },
#         {
#           "Kieu Ky": []
#         },
#         {
#           "Vinh Tuy": []
#         },
#         {
#           "Ngoc Ha": []
#         },
#         {
#           "Thanh Nhàn": []
#         },
#         {
#           "Co Nhue": []
#         },
#         {
#           "Yên Bài": []
#         },
#         {
#           "Xuan Dinh": []
#         }
#       ]
#     },
#     {
#       "Ho Chi Minh City": [
#         {
#           "Cần Giờ": []
#         },
#         {
#           "Bình Chánh": []
#         },
#         {
#           "Hóc Môn": []
#         },
#         {
#           "Thành phố Hồ Chí Minh": []
#         },
#         {
#           "Go Vap": []
#         },
#         {
#           "Củ Chi": []
#         },
#         {
#           "Da Kao": []
#         },
#         {
#           "Hô Chi Minh Ville": []
#         },
#         {
#           "Gò May": []
#         },
#         {
#           "Phu Nhuan": []
#         },
#         {
#           "Linh Xúân": []
#         },
#         {
#           "Xóm Bình Phước": []
#         },
#         {
#           "Gò Công": []
#         }
#       ]
#     },
#     {
#       "Tuyên Quang": [
#         {
#           "Tuyên Quang": []
#         }
#       ]
#     },
#     {
#       "Nam Định": [
#         {
#           "Nam Định": []
#         }
#       ]
#     },
#     {
#       "Da Nang": []
#     },
#     {
#       "Thái Bình": [
#         {
#           "Thái Bình": []
#         },
#         {
#           "Hung Nhan": []
#         },
#         {
#           "Dong Dong": []
#         },
#         {
#           "Quynh Coi": []
#         }
#       ]
#     },
#     {
#       "Hai Phong": [
#         {
#           "Haiphong": []
#         },
#         {
#           "An Duong": []
#         },
#         {
#           "Cat Hai": []
#         },
#         {
#           "Vinh Bao": []
#         },
#         {
#           "Cát Bà": []
#         }
#       ]
#     },
#     {
#       "Tiền Giang": [
#         {
#           "Vàm Rầy (1)": []
#         },
#         {
#           "Long An": [
#             {
#               "Long Hoa": []
#             },
#             {
#               "Can Gioc": []
#             },
#             {
#               "Binh Hiep": []
#             }
#           ]
#         },
#         {
#           "Mitho": []
#         },
#         {
#           "Châu Thành": []
#         },
#         {
#           "Vĩnh Bình (1)": []
#         },
#         {
#           "Ấp Bắc": []
#         },
#         {
#           "Rach Soi": []
#         },
#         {
#           "Soc Xoai": []
#         },
#         {
#           "Ap Tan Thanh (4)": []
#         },
#         {
#           "Giong Ba Ninh": []
#         },
#         {
#           "Phu Quoc": []
#         },
#         {
#           "Ap My Tho": []
#         },
#         {
#           "Duong Dong": []
#         }
#       ]
#     },
#     {
#       "Hue": []
#     },
#     {
#       "Lâm Ðồng": [
#         {
#           "Djrott": []
#         },
#         {
#           "Tung Nghia": []
#         },
#         {
#           "Kao RThi": []
#         },
#         {
#           "Lac Lam": []
#         },
#         {
#           "Pantar": []
#         },
#         {
#           "BSar Dong": []
#         }
#       ]
#     },
#     {
#       "Hanam": [
#         {
#           "Ha-Nam": []
#         }
#       ]
#     },
#     {
#       "Ninh Thuận": [
#         {
#           "Phan Rang-Tháp Chàm": []
#         },
#         {
#           "Xa Phan Thiet": []
#         },
#         {
#           "An Phuoc": []
#         },
#         {
#           "Fan Thiet": []
#         },
#         {
#           "Tánh Linh": []
#         }
#       ]
#     },
#     {
#       "Đắc Lắk": [
#         {
#           "Buôn Ma Thuột": []
#         },
#         {
#           "Bon Bu Bo Dak Nong": []
#         },
#         {
#           "Trung Hòa": []
#         },
#         {
#           "Buôn Krông Bông": []
#         },
#         {
#           "Xuong Cua May Dak Song": []
#         },
#         {
#           "Buon Bip": []
#         },
#         {
#           "Buôn Pok": []
#         },
#         {
#           "Buôn Hô": []
#         },
#         {
#           "Ã?Uc Minh": []
#         },
#         {
#           "Buon Trap": []
#         },
#         {
#           "Ban Dak": []
#         }
#       ]
#     },
#     {
#       "Nghệ An": [
#         {
#           "Thái Hõa": []
#         },
#         {
#           "Nam �Àn": []
#         },
#         {
#           "Quynh Luu": []
#         },
#         {
#           "Phu Dien Chau": []
#         },
#         {
#           "Nghia Ã?An": []
#         },
#         {
#           "Cầu Giát": []
#         },
#         {
#           "Cho Do Luong": []
#         },
#         {
#           "Vin": []
#         }
#       ]
#     },
#     {
#       "Hưng Yên": [
#         {
#           "Hung Yen": []
#         }
#       ]
#     },
#     {
#       "Ap Binh Duong (1)": []
#     },
#     {
#       "Nghe Tinh": [
#         {
#           "Vinh Ang": []
#         },
#         {
#           "Thanh Hoa": []
#         },
#         {
#           "Thái Bình": []
#         }
#       ]
#     },
#     {
#       "Ðồng Tháp": [
#         {
#           "Thanh Bình": []
#         },
#         {
#           "Tràm Chim": []
#         },
#         {
#           "Sóc Sa Rài": []
#         }
#       ]
#     },
#     {
#       "Hà Nam": [
#         {
#           "Kim Bang": []
#         },
#         {
#           "My Loc": []
#         },
#         {
#           "Xuan Thuy": []
#         },
#         {
#           "Hòa Dinh": []
#         },
#         {
#           "Trinh Xuyen": []
#         },
#         {
#           "Hoa Mac": []
#         },
#         {
#           "Chuyen Thien": []
#         },
#         {
#           "Yên Bài": []
#         }
#       ]
#     },
#     {
#       "Ap Bao Binh": []
#     },
#     {
#       "Hòa Bình": [
#         {
#           "Hòa Bình": []
#         },
#         {
#           "Luong Son": []
#         }
#       ]
#     },
#     {
#       "Song Be": [
#         {
#           "Binh Chuan": []
#         },
#         {
#           "Phu Cuong": []
#         },
#         {
#           "Sông-Bé": []
#         }
#       ]
#     },
#     {
#       "Hà Tĩnh": [
#         {
#           "Ha Tin": []
#         },
#         {
#           "Hương Khê": []
#         }
#       ]
#     },
#     {
#       "Ha Tuyen": [
#         {
#           "Quang Giao": []
#         },
#         {
#           "Po Ly Hgai": []
#         }
#       ]
#     },
#     {
#       "Khánh Hòa": [
#         {
#           "Ninh Hòa": []
#         },
#         {
#           "Hương Cẩm Thủy": []
#         },
#         {
#           "Khanh Hoa": []
#         },
#         {
#           "Diên Khánh": []
#         },
#         {
#           "Cam Ranh Port": []
#         },
#         {
#           "Như Xuân": []
#         },
#         {
#           "Cam Lâm": []
#         },
#         {
#           "Hương Bá Thước": []
#         },
#         {
#           "Vân Am": []
#         },
#         {
#           "Truong Tan": []
#         },
#         {
#           "Hoang Pho": []
#         }
#       ]
#     },
#     {
#       "Soc Trang": [
#         {
#           "Tinh": []
#         },
#         {
#           "Sài Gòn": []
#         },
#         {
#           "Ap Nha Tho": []
#         },
#         {
#           "Châu Thanh": []
#         },
#         {
#           "Xóm Phú An": []
#         }
#       ]
#     },
#     {
#       "Vĩnh Phúc": [
#         {
#           "Tam Đảo": []
#         },
#         {
#           "Phu Lo": []
#         },
#         {
#           "Vieh Yen": []
#         },
#         {
#           "Huong Canh": []
#         },
#         {
#           "Lang Son": [
#             {
#               "Ban Nhang": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "Thoi Lai": []
#     },
#     {
#       "Quảng Nam": [
#         {
#           "Quang Nam": []
#         },
#         {
#           "Que Son": []
#         },
#         {
#           "Dong Quang": []
#         },
#         {
#           "Binh Duong": []
#         }
#       ]
#     },
#     {
#       "Gia Lai": [
#         {
#           "Plây Ku": []
#         },
#         {
#           "Tinh Pleiku": []
#         },
#         {
#           "Gia Lai": []
#         }
#       ]
#     },
#     {
#       "Gia Kiem": []
#     },
#     {
#       "Hải Dương": [
#         {
#           "Haidöng": []
#         }
#       ]
#     },
#     {
#       "Binh Minh": [
#         {
#           "Bồng Sơn": []
#         },
#         {
#           "Hoài Nhon": []
#         },
#         {
#           "Hoài Ân": []
#         },
#         {
#           "Phú Phong": []
#         },
#         {
#           "Qui Nhon": []
#         }
#       ]
#     },
#     {
#       "Kon Tum": [
#         {
#           "Kon Tum": []
#         }
#       ]
#     },
#     {
#       "Quảng Ninh": [
#         {
#           "Le Thuy": []
#         },
#         {
#           "Trang Bach": []
#         },
#         {
#           "Cẩm Phả Port": []
#         },
#         {
#           "Ha Coi": []
#         },
#         {
#           "Khê Mao": []
#         },
#         {
#           "Quảng Yên": []
#         },
#         {
#           "Cai Rong": []
#         },
#         {
#           "Cam Pha Mines": []
#         },
#         {
#           "Cua Ong": []
#         },
#         {
#           "Hoàn Lão": []
#         },
#         {
#           "Biểu Nghi": []
#         },
#         {
#           "Ã?Am Ha": []
#         },
#         {
#           "Hong Gai": []
#         },
#         {
#           "Ha Lam": []
#         }
#       ]
#     },
#     {
#       "Rach Gia": []
#     },
#     {
#       "An Giang": [
#         {
#           "Chaudok": []
#         },
#         {
#           "Phu My": []
#         },
#         {
#           "Chau Phú": []
#         },
#         {
#           "An Nong": []
#         },
#         {
#           "Cho Moi": []
#         },
#         {
#           "Hoa Lac": []
#         }
#       ]
#     },
#     {
#       "Bìn Phước": [
#         {
#           "Hớn Quản": []
#         },
#         {
#           "Lộc Ninh": []
#         },
#         {
#           "Bình Long": []
#         },
#         {
#           "Dong Xoa": []
#         }
#       ]
#     },
#     {
#       "Tây Ninh": [
#         {
#           "Gò Dầu Hạ": []
#         },
#         {
#           "Katum": []
#         },
#         {
#           "Tha La": []
#         }
#       ]
#     },
#     {
#       "Ho Nai": []
#     },
#     {
#       "Ninh Bình": [
#         {
#           "Phát Diệm": []
#         },
#         {
#           "Ninbinh": []
#         },
#         {
#           "Nho Quan": []
#         }
#       ]
#     },
#     {
#       "Lào Cai": [
#         {
#           "Laokai": []
#         }
#       ]
#     },
#     {
#       "Hai Hung": [
#         {
#           "Lai Cách": []
#         },
#         {
#           "Nhu Quynh": []
#         },
#         {
#           "Tiên Quán": []
#         }
#       ]
#     },
#     {
#       "Nghia Binh": [
#         {
#           "Binh Dinh": []
#         },
#         {
#           "Diêu Trì": []
#         },
#         {
#           "Truc Dao (1)": []
#         },
#         {
#           "Vinh Long (1)": []
#         },
#         {
#           "An Giang (4)": []
#         }
#       ]
#     },
#     {
#       "Binh Tri Thien": [
#         {
#           "Quang Ninh": []
#         },
#         {
#           "Liêm Công Tây (1)": []
#         },
#         {
#           "Võ Xá": []
#         },
#         {
#           "Lý Hòa": []
#         },
#         {
#           "Cao Bang": []
#         }
#       ]
#     },
#     {
#       "Bạc Liêu": [
#         {
#           "Huyện Thạnh Trị": []
#         },
#         {
#           "Hòa Bình": []
#         }
#       ]
#     },
#     {
#       "Phú Thọ": [
#         {
#           "Phu Tho": []
#         },
#         {
#           "Vietri": []
#         }
#       ]
#     },
#     {
#       "Ðồng Nai": [
#         {
#           "Xuân Lộc": []
#         }
#       ]
#     },
#     {
#       "Bà Rịa-Vũng Tàu": [
#         {
#           "Cap-Saint-Jacques": []
#         },
#         {
#           "Xa Vung Tau": []
#         }
#       ]
#     },
#     {
#       "Thac Tri An": []
#     },
#     {
#       "Hoang Lien Son": [
#         {
#           "Ha Nam": []
#         },
#         {
#           "Dong Thap": []
#         }
#       ]
#     },
#     {
#       "Ha Son Binh": [
#         {
#           "Phu Luu Te": []
#         },
#         {
#           "Ung Hoa": []
#         },
#         {
#           "Xuân Mai": []
#         },
#         {
#           "Na Noi": []
#         },
#         {
#           "Trai Vang": []
#         }
#       ]
#     },
#     {
#       "Quảng Trị": [
#         {
#           "�Ông Hà": []
#         },
#         {
#           "Hồ Xá": []
#         }
#       ]
#     },
#     {
#       "Bắc Kạn": [
#         {
#           "Bac Can": []
#         }
#       ]
#     },
#     {
#       "Cẩn Thỏ": [
#         {
#           "Long My": []
#         }
#       ]
#     },
#     {
#       "Xa Dau Giay": []
#     },
#     {
#       "Binh Chau": []
#     },
#     {
#       "Hà Giang": [
#         {
#           "Bắc Quang": []
#         },
#         {
#           "Yên Minh": []
#         }
#       ]
#     },
#     {
#       "Xã Bình Hòa": []
#     },
#     {
#       "Quảng Ngãi": [
#         {
#           "Binh Son": []
#         }
#       ]
#     },
#     {
#       "Thuin Hai": [
#         {
#           "Lagi": []
#         }
#       ]
#     },
#     {
#       "Lai Châu": [
#         {
#           "Binh Lu": []
#         }
#       ]
#     },
#     {
#       "Phu Khanh": [
#         {
#           "Ninh Bình": []
#         }
#       ]
#     },
#     {
#       "Tam Hiep": []
#     },
#     {
#       "Phú Yên": [
#         {
#           "Tuy An": []
#         },
#         {
#           "Toy Hoa": []
#         }
#       ]
#     },
#     {
#       "Cà Mau": [
#         {
#           "Thới Bình": []
#         }
#       ]
#     },
#     {
#       "Bến Tre": [
#         {
#           "Trúc Giang": []
#         },
#         {
#           "Huong Thanh Phu": []
#         },
#         {
#           "Ben": []
#         }
#       ]
#     },
#     {
#       "Hi Bac": [
#         {
#           "Phuong Mao": []
#         },
#         {
#           "Tu Son": []
#         },
#         {
#           "Vinh": []
#         }
#       ]
#     },
#     {
#       "Cao Bằng": [
#         {
#           "Cách Linh": []
#         },
#         {
#           "Trung Khanh Phu": []
#         }
#       ]
#     },
#     {
#       "Phu Giáo": []
#     },
#     {
#       "Trà Vinh": [
#         {
#           "Song Loc": []
#         },
#         {
#           "Châu Thành": []
#         }
#       ]
#     },
#     {
#       "Xa Trang Bom": []
#     },
#     {
#       "Cu Bi": []
#     },
#     {
#       "Xã Bình Long": []
#     },
#     {
#       "Minh Hai": [
#         {
#           "Ap Binh Thuan": []
#         }
#       ]
#     },
#     {
#       "Gia Lai-Cong Tum": [
#         {
#           "Kon Tum (2)": []
#         }
#       ]
#     },
#     {
#       "Hà Tây": [
#         {
#           "Hà �Ông": []
#         }
#       ]
#     },
#     {
#       "Bac Thai": [
#         {
#           "Thai": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Nam Truc": []
# }
# {
#   "Hải Dương": []
# }
# {
#   "Biên Hòa": []
# }
# {
#   "Lạng Sơn": []
# }
# {
#   "Cà Mau": []
# }
# {
#   "Can Duoc": []
# }
# {
#   "Cao Bang": []
# }
# {
#   "Taiwan": [
#     {
#       "Taipei": []
#     },
#     {
#       "Hsinchu": []
#     },
#     {
#       "Tainan": []
#     },
#     {
#       "Taichung": []
#     },
#     {
#       "Kaohsiung": []
#     },
#     {
#       "TAi-Wan": [
#         {
#           "Tatuliao": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Nigeria": [
#     {
#       "Benin": []
#     },
#     {
#       "Abuja": []
#     },
#     {
#       "Ekiti": [
#         {
#           "Ijero Ekiti": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Ninh Bình": []
# }
# {
#   "Nghi Loc": []
# }
# {
#   "United Kingdom": [
#     {
#       "London": []
#     },
#     {
#       "Manchester": []
#     },
#     {
#       "Neath Port Talbot": [
#         {
#           "Port Talbot": []
#         }
#       ]
#     },
#     {
#       "Glasgow": []
#     },
#     {
#       "Nottingham": []
#     }
#   ]
# }
# {
#   "Vinh": []
# }
# {
#   "Thailand": [
#     {
#       "Bangkok": []
#     },
#     {
#       "Lop Buri": [
#         {
#           "Chai Badan": []
#         }
#       ]
#     },
#     {
#       "Chiang Mai": [
#         {
#           "Ban Dong Nai": []
#         }
#       ]
#     },
#     {
#       "Phra Nakhon Si Ayutthaya": [
#         {
#           "Ayuthaya": []
#         }
#       ]
#     },
#     {
#       "Phayao": [
#         {
#           "Chiang Kham": []
#         }
#       ]
#     },
#     {
#       "Surin": []
#     }
#   ]
# }
# {
#   "Jamaica": [
#     {
#       "Lucea": []
#     }
#   ]
# }
# {
#   "Indonesia": [
#     {
#       "Bali": [
#         {
#           "Denpasar": []
#         },
#         {
#           "Negara": []
#         }
#       ]
#     },
#     {
#       "Nusa Tenggara Barat": [
#         {
#           "Lombok": []
#         },
#         {
#           "Karangasem Amlapura": []
#         }
#       ]
#     },
#     {
#       "Jawa Barat": [
#         {
#           "Bumi Serpong": []
#         },
#         {
#           "Cikampek": []
#         }
#       ]
#     },
#     {
#       "Kalimantan Timur": [
#         {
#           "Tanahgrogot": []
#         },
#         {
#           "Sangkulirang": []
#         },
#         {
#           "Bontang": []
#         },
#         {
#           "Tarakan": []
#         }
#       ]
#     },
#     {
#       "Jakarta": []
#     },
#     {
#       "Bogor": []
#     },
#     {
#       "Sulawesi Tengah": [
#         {
#           "Sigi": []
#         },
#         {
#           "Paloe": []
#         }
#       ]
#     },
#     {
#       "Riau": [
#         {
#           "Duri": []
#         }
#       ]
#     },
#     {
#       "Jawa Timur": [
#         {
#           "Banyuwangi": []
#         },
#         {
#           "Jombang": []
#         },
#         {
#           "Sidoarjo": []
#         }
#       ]
#     },
#     {
#       "Sulawesi Selatan": [
#         {
#           "Makale": []
#         },
#         {
#           "Pasangkayu": []
#         },
#         {
#           "Pinrang": []
#         },
#         {
#           "Mamasa": []
#         }
#       ]
#     },
#     {
#       "Surabaya": []
#     },
#     {
#       "Jawa Tengah": [
#         {
#           "Kebumen": []
#         }
#       ]
#     },
#     {
#       "Medan": []
#     },
#     {
#       "Sumatera Selatan": [
#         {
#           "Baturaja": []
#         },
#         {
#           "Lahat": []
#         }
#       ]
#     },
#     {
#       "Sumatera Barat": [
#         {
#           "Koto Padang": []
#         }
#       ]
#     },
#     {
#       "Aceh": [
#         {
#           "Lhoksukon": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Germany": [
#     {
#       "Berlin": []
#     },
#     {
#       "Hamburg": []
#     },
#     {
#       "Niedersachsen": [
#         {
#           "Bordenau": []
#         }
#       ]
#     },
#     {
#       "Frankfurt": []
#     },
#     {
#       "Heidelberg": []
#     },
#     {
#       "Oldenburg": []
#     },
#     {
#       "Speyer": []
#     }
#   ]
# }
# {
#   "Rach Gia": []
# }
# {
#   "South Carolina": [
#     {
#       "Charlotte": []
#     },
#     {
#       "Greensboro": []
#     },
#     {
#       "Durham": []
#     },
#     {
#       "Fort Mill": []
#     },
#     {
#       "Myrtle Beach": []
#     },
#     {
#       "Colombia": [
#         {
#           "Bogotá": []
#         },
#         {
#           "Cartagena": []
#         }
#       ]
#     },
#     {
#       "Denver": []
#     }
#   ]
# }
# {
#   "France": [
#     {
#       "Provence-Alpes-Cote D'Azur": [
#         {
#           "Les Saintes Maries De La Mer": []
#         }
#       ]
#     },
#     {
#       "Paris": []
#     },
#     {
#       "Lyon": []
#     },
#     {
#       "Midi-Pyrenees": [
#         {
#           "Bagnères-De-Luchon": []
#         }
#       ]
#     },
#     {
#       "Troyes": []
#     },
#     {
#       "Toulouse": []
#     },
#     {
#       "Aix-en-Provence": []
#     },
#     {
#       "Maisons-Alfort": []
#     }
#   ]
# }
# {
#   "Zimbabwe": [
#     {
#       "Harare": []
#     }
#   ]
# }
# {
#   "Nghi Xuân": []
# }
# {
#   "Gia Nghia": []
# }
# {
#   "Thanh Hóa": []
# }
# {
#   "Pleiku": []
# }
# {
#   "Tinh Gia": []
# }
# {
#   "Singapore": [
#     {
#       "Buona Vista": []
#     }
#   ]
# }
# {
#   "Vĩnh Long": []
# }
# {
#   "China": [
#     {
#       "Macao": []
#     },
#     {
#       "Beijing": []
#     },
#     {
#       "Chongqing": []
#     },
#     {
#       "Tianjin": []
#     },
#     {
#       "Fujian": [
#         {
#           "Longan": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Hà Tĩnh": []
# }
# {
#   "Italy": [
#     {
#       "Florence": []
#     },
#     {
#       "Milan": []
#     },
#     {
#       "Naples": []
#     },
#     {
#       "Emilia-Romagna": [
#         {
#           "Milano Marittima": []
#         }
#       ]
#     },
#     {
#       "Rome": []
#     }
#   ]
# }
# {
#   "Tuy Hòa": []
# }
# {
#   "Kien Luong": []
# }
# {
#   "Di An": []
# }
# {
#   "Jember": []
# }
# {
#   "Tra Vinh": []
# }
# {
#   "Can Tho": []
# }
# {
#   "Phuket (city)": []
# }
# {
#   "Ben Cat": []
# }
# {
#   "Nha Trang": []
# }
# {
#   "Algeria": [
#     {
#       "Ain Defla": [
#         {
#           "'Aïn Defla": []
#         }
#       ]
#     },
#     {
#       "Mascara": []
#     }
#   ]
# }
# {
#   "Czech Republic": [
#     {
#       "Brno": []
#     },
#     {
#       "Plzeňský Kraj": [
#         {
#           "Cban": []
#         }
#       ]
#     },
#     {
#       "Plzen": []
#     },
#     {
#       "Prague": []
#     }
#   ]
# }
# {
#   "Tây Ninh": []
# }
# {
#   "Malaysia": [
#     {
#       "Kuala Lumpur": [
#         {
#           "Kampong Sungai Mulia": []
#         }
#       ]
#     },
#     {
#       "Pulau Pinang": [
#         {
#           "Tasek Glugor": []
#         }
#       ]
#     },
#     {
#       "Kuching": []
#     },
#     {
#       "Shah Alam": []
#     },
#     {
#       "Terengganu": [
#         {
#           "Kemaman": []
#         }
#       ]
#     },
#     {
#       "Selangor": [
#         {
#           "Kampong Tanjong Sepat": []
#         }
#       ]
#     },
#     {
#       "Penang": []
#     },
#     {
#       "Johor": [
#         {
#           "Pasir Gudang": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Thu Dau Mot": []
# }
# {
#   "Perak": [
#     {
#       "Ipoh": []
#     }
#   ]
# }
# {
#   "Bắc Ninh": []
# }
# {
#   "Bao Loc": []
# }
# {
#   "Điện Biên Phủ": []
# }
# {
#   "Yên Thành": []
# }
# {
#   "Egypt": [
#     {
#       "Cairo": []
#     },
#     {
#       "Alexandria": []
#     }
#   ]
# }
# {
#   "Tam Ky": []
# }
# {
#   "Dak Mil": []
# }
# {
#   "Malang": []
# }
# {
#   "Rajshahi": []
# }
# {
#   "Thái Nguyên": []
# }
# {
#   "Vung Tau": []
# }
# {
#   "Da Lat": []
# }
# {
#   "Long Xuyên": []
# }
# {
#   "Long Thanh": []
# }
# {
#   "Bangladesh": [
#     {
#       "Dhaka": [
#         {
#           "Dubail": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Bac Giang": []
# }
# {
#   "Debrecen": []
# }
# {
#   "Quang Ngai": []
# }
# {
#   "Tokyo": [
#     {
#       "Toshima": []
#     },
#     {
#       "Fuchu": []
#     },
#     {
#       "Shibuya": []
#     }
#   ]
# }
# {
#   "Lào Cai": []
# }
# {
#   "Davao City": []
# }
# {
#   "Hong Kong": []
# }
# {
#   "Phan Thiet": []
# }
# {
#   "Western Australia": [
#     {
#       "Perth": []
#     },
#     {
#       "Sydney": []
#     },
#     {
#       "Victoria": [
#         {
#           "Melbourne": []
#         }
#       ]
#     },
#     {
#       "Queensland": [
#         {
#           "Brisbane": []
#         },
#         {
#           "Gold Coast": []
#         }
#       ]
#     },
#     {
#       "New South Wales": [
#         {
#           "Glenmore Park": []
#         },
#         {
#           "Coffs Harbour": []
#         },
#         {
#           "Newcastle": []
#         }
#       ]
#     },
#     {
#       "Geraldton": []
#     }
#   ]
# }
# {
#   "Xuan Truong": []
# }
# {
#   "Turkey": [
#     {
#       "Istanbul": [
#         {
#           "Yeniköy": []
#         }
#       ]
#     },
#     {
#       "İzmir": []
#     }
#   ]
# }
# {
#   "Hà Giang": []
# }
# {
#   "Hungary": [
#     {
#       "Budapest": []
#     },
#     {
#       "Heves": [
#         {
#           "Mezotarkany": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Moc Chau": []
# }
# {
#   "Minnesota": [
#     {
#       "Minneapolis": []
#     },
#     {
#       "Hugo": []
#     },
#     {
#       "Eden Prairie": []
#     },
#     {
#       "Duluth": []
#     }
#   ]
# }
# {
#   "Ha Long": []
# }
# {
#   "Texas": [
#     {
#       "Paris": []
#     },
#     {
#       "Houston": []
#     },
#     {
#       "La Belle": []
#     },
#     {
#       "Dallas": []
#     },
#     {
#       "Austin": []
#     },
#     {
#       "San Marcos": []
#     },
#     {
#       "Amarillo": []
#     },
#     {
#       "Perryton": []
#     },
#     {
#       "Spring": []
#     }
#   ]
# }
# {
#   "Phú Quý": []
# }
# {
#   "Laos": [
#     {
#       "Vientiane": [
#         {
#           "Vien Chang": []
#         },
#         {
#           "Vieng-Chan": []
#         },
#         {
#           "Vientane": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "India": [
#     {
#       "Karbi Anglong": []
#     },
#     {
#       "Indore": []
#     },
#     {
#       "Chandigarh": []
#     }
#   ]
# }
# {
#   "Bến Tre": []
# }
# {
#   "Đồng Hới": []
# }
# {
#   "Kagoshima": [
#     {
#       "Kanoya": []
#     }
#   ]
# }
# {
#   "Tân Phú": []
# }
# {
#   "Quảng Trị": []
# }
# {
#   "Buon Me Thuot": []
# }
# {
#   "Korea": [
#     {
#       "Seoul": []
#     }
#   ]
# }
# {
#   "Ben Luc": []
# }
# {
#   "Hàm Yên": []
# }
# {
#   "Son La": []
# }
# {
#   "Anh Son": []
# }
# {
#   "Viet Tri": []
# }
# {
#   "Makati": []
# }
# {
#   "Tuong Duong": []
# }
# {
#   "Duy Xuyên": []
# }
# {
#   "Ontario": [
#     {
#       "Hamilton": []
#     },
#     {
#       "Toronto": []
#     },
#     {
#       "Ottawa": []
#     },
#     {
#       "Brantford": []
#     }
#   ]
# }
# {
#   "Vinh Tuong": []
# }
# {
#   "Dong Ha": []
# }
# {
#   "My Tho": []
# }
# {
#   "Phan Rang": []
# }
# {
#   "Cao Lãnh": []
# }
# {
#   "Long An": [
#     {
#       "Tân An": []
#     },
#     {
#       "Thanh Hoa": []
#     }
#   ]
# }
# {
#   "Curaçao": [
#     {
#       "Australie": []
#     }
#   ]
# }
# {
#   "Netherlands": [
#     {
#       "Friesland": [
#         {
#           "Oudega": []
#         }
#       ]
#     },
#     {
#       "Amsterdam": []
#     },
#     {
#       "Nijmegen": []
#     },
#     {
#       "Noord": [
#         {
#           "Bavel": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Phú Thọ": []
# }
# {
#   "Cebu City": []
# }
# {
#   "Luc Nam": []
# }
# {
#   "Dalad Qi": []
# }
# {
#   "Lumajang": []
# }
# {
#   "Tangerang": []
# }
# {
#   "New York": [
#     {
#       "New York": []
#     },
#     {
#       "New Rochelle": []
#     },
#     {
#       "Brooklyn": []
#     },
#     {
#       "Rochester": []
#     },
#     {
#       "Scarsdale": []
#     },
#     {
#       "Amherst": []
#     },
#     {
#       "Monticello": []
#     },
#     {
#       "Queens": []
#     },
#     {
#       "Paris": []
#     },
#     {
#       "Geneva": []
#     },
#     {
#       "Hicksville": []
#     },
#     {
#       "New City": []
#     },
#     {
#       "Manhattan": []
#     },
#     {
#       "Ithaca": []
#     },
#     {
#       "Binghamton": []
#     }
#   ]
# }
# {
#   "Kupang": []
# }
# {
#   "Jászberény": []
# }
# {
#   "Saitama": [
#     {
#       "Honjo": []
#     }
#   ]
# }
# {
#   "California": [
#     {
#       "Los Angeles": []
#     },
#     {
#       "San Francisco": []
#     },
#     {
#       "Elk Grove": []
#     },
#     {
#       "California City": []
#     },
#     {
#       "Fresno": []
#     },
#     {
#       "Garden Grove": []
#     },
#     {
#       "Stanton": []
#     },
#     {
#       "Sacramento": []
#     },
#     {
#       "Costa Mesa": []
#     },
#     {
#       "Pleasanton": []
#     },
#     {
#       "Ontario": []
#     },
#     {
#       "Corona": []
#     },
#     {
#       "Rosemead": []
#     },
#     {
#       "San Jose": []
#     },
#     {
#       "Santa Monica": []
#     },
#     {
#       "Irvine": []
#     },
#     {
#       "Fountain Valley": []
#     },
#     {
#       "Fullerton": []
#     },
#     {
#       "Apple Valley": []
#     },
#     {
#       "Carlsbad": []
#     },
#     {
#       "San Gabriel": []
#     },
#     {
#       "Berkeley": []
#     },
#     {
#       "Highland": []
#     },
#     {
#       "Pasadena": []
#     },
#     {
#       "Bakersfield": []
#     },
#     {
#       "Westminster": []
#     }
#   ]
# }
# {
#   "Jambi City": []
# }
# {
#   "Moldova": [
#     {
#       "Chisinau": []
#     }
#   ]
# }
# {
#   "Than Uyên": []
# }
# {
#   "Desa": []
# }
# {
#   "Saudi Arabia": [
#     {
#       "Tabuk": []
#     },
#     {
#       "Riyadh": []
#     }
#   ]
# }
# {
#   "Kazakhstan": [
#     {
#       "Astana": []
#     },
#     {
#       "Almaty": []
#     }
#   ]
# }
# {
#   "Pagadian City": []
# }
# {
#   "Bandung": []
# }
# {
#   "Greece": [
#     {
#       "Athens": []
#     }
#   ]
# }
# {
#   "Sanggau": []
# }
# {
#   "Mandalay": []
# }
# {
#   "Pekanbaru": []
# }
# {
#   "Yangon": []
# }
# {
#   "Chad": [
#     {
#       "Moyen-Chari": [
#         {
#           "Jember": []
#         }
#       ]
#     },
#     {
#       "Wadi Fira": [
#         {
#           "Saigon": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Brazil": [
#     {
#       "Rio Grande Do Sul": [
#         {
#           "Tôrres": []
#         }
#       ]
#     },
#     {
#       "Bahia": [
#         {
#           "Salvador": []
#         },
#         {
#           "Duas E Dois": []
#         },
#         {
#           "Valença": []
#         }
#       ]
#     },
#     {
#       "Sao Paulo": [
#         {
#           "Praia Grande": []
#         }
#       ]
#     },
#     {
#       "Pernambuco": [
#         {
#           "Taquaritinga Do Norte": []
#         }
#       ]
#     },
#     {
#       "Belém": []
#     },
#     {
#       "Sorocaba": []
#     }
#   ]
# }
# {
#   "Cua Lo": []
# }
# {
#   "Quebec": [
#     {
#       "Fox River": []
#     },
#     {
#       "Montreal": []
#     }
#   ]
# }
# {
#   "Ba Ria": []
# }
# {
#   "Lai Vung": []
# }
# {
#   "Thanh Chuong": []
# }
# {
#   "Leyte": [
#     {
#       "Palompon": []
#     }
#   ]
# }
# {
#   "Johor Bahru": []
# }
# {
#   "Lai Chau": []
# }
# {
#   "Cam Pha": []
# }
# {
#   "Mexico": [
#     {
#       "Saltillo": []
#     },
#     {
#       "Mexico": [
#         {
#           "Cañada": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Cái Bè": []
# }
# {
#   "Sudan": [
#     {
#       "Khartoum": []
#     }
#   ]
# }
# {
#   "Bondowoso": []
# }
# {
#   "Uruguay": [
#     {
#       "Canelones": [
#         {
#           "Paso De Pache": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Son Tay": []
# }
# {
#   "Tuy Phong": []
# }
# {
#   "Japan": [
#     {
#       "Hokkaido": [
#         {
#           "Esashi-gun": []
#         }
#       ]
#     },
#     {
#       "Aichi": [
#         {
#           "Nagoya-shi": []
#         }
#       ]
#     },
#     {
#       "Tokyo": [
#         {
#           "Chiyoda-ku": []
#         },
#         {
#           "Koto-ku": []
#         }
#       ]
#     },
#     {
#       "Kanagawa": [
#         {
#           "Ayase-shi": []
#         },
#         {
#           "Sagamihara-shi": []
#         }
#       ]
#     },
#     {
#       "Saitama": [
#         {
#           "Higashimatsuyama-shi": []
#         }
#       ]
#     },
#     {
#       "Nara": [
#         {
#           "Yoshino-gun": []
#         }
#       ]
#     },
#     {
#       "Hyogo": [
#         {
#           "Toyoka-shi": []
#         }
#       ]
#     },
#     {
#       "Fukuoka": [
#         {
#           "Fukuoka-shi": []
#         }
#       ]
#     },
#     {
#       "Shiga": [
#         {
#           "Higashiomi-shi": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Alabama": [
#     {
#       "Roanoke": []
#     },
#     {
#       "Huntsville": []
#     }
#   ]
# }
# {
#   "South Korea": [
#     {
#       "Busan": []
#     }
#   ]
# }
# {
#   "Nhon Trach": []
# }
# {
#   "Marcelândia": []
# }
# {
#   "Bac Lieu": []
# }
# {
#   "Ukraine": [
#     {
#       "Kharkov": []
#     }
#   ]
# }
# {
#   "Russia": [
#     {
#       "Moscow": []
#     },
#     {
#       "Vladivostok": []
#     },
#     {
#       "Engels": []
#     },
#     {
#       "TulSkaya Oblast": [
#         {
#           "Lomintsevskiy": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Osaka": []
# }
# {
#   "Phúc Yên": []
# }
# {
#   "Hồng Ngự": []
# }
# {
#   "Móng Cái": []
# }
# {
#   "Yên Bái": []
# }
# {
#   "Nganjuk": []
# }
# {
#   "Can Giuoc": []
# }
# {
#   "Miskovice": []
# }
# {
#   "South Australia": [
#     {
#       "Adelaide": []
#     }
#   ]
# }
# {
#   "Milton Keynes": []
# }
# {
#   "Dau Tieng": []
# }
# {
#   "Thanh Khê": []
# }
# {
#   "Szerencs": []
# }
# {
#   "Samarinda": []
# }
# {
#   "Quy Nhon": []
# }
# {
#   "Pakistan": [
#     {
#       "Peshawar": []
#     },
#     {
#       "Lahore": []
#     }
#   ]
# }
# {
#   "Austria": [
#     {
#       "Vienna": []
#     }
#   ]
# }
# {
#   "Kidima": []
# }
# {
#   "Bát Xát": []
# }
# {
#   "Rangamati": []
# }
# {
#   "Arizona": [
#     {
#       "Phoenix": []
#     },
#     {
#       "Lake Havasu City": []
#     }
#   ]
# }
# {
#   "India": [
#     {
#       "Indianapolis": []
#     },
#     {
#       "Westfield": []
#     }
#   ]
# }
# {
#   "Bình Liêu": []
# }
# {
#   "Tân Châu": []
# }
# {
#   "Loc Ninh": []
# }
# {
#   "Tân Thành": []
# }
# {
#   "Bac Kan": []
# }
# {
#   "Sirajganj": []
# }
# {
#   "Sông Cầu": []
# }
# {
#   "Tiên Yên": []
# }
# {
#   "Fernandópolis": []
# }
# {
#   "Tuy Phuoc": []
# }
# {
#   "Trang Bom": []
# }
# {
#   "Tulungagung": []
# }
# {
#   "Nevada": [
#     {
#       "Las Vegas": []
#     }
#   ]
# }
# {
#   "Phu Ly": []
# }
# {
#   "Pangasinan": [
#     {
#       "Alaminos": []
#     }
#   ]
# }
# {
#   "Long My": []
# }
# {
#   "Morocco": [
#     {
#       "Rabat": []
#     },
#     {
#       "Marrakech": [
#         {
#           "Merrakex": []
#         }
#       ]
#     },
#     {
#       "Rabat-Sale": [
#         {
#           "Sla": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Dien Chau": []
# }
# {
#   "Michigan": [
#     {
#       "Kentwood": []
#     },
#     {
#       "Grand Rapids": []
#     },
#     {
#       "Assyria": []
#     }
#   ]
# }
# {
#   "Phnom Penh": []
# }
# {
#   "Di Linh": []
# }
# {
#   "Iceland": [
#     {
#       "Reykjavík": []
#     },
#     {
#       "Mitchelstown": []
#     }
#   ]
# }
# {
#   "Alor Gajah": []
# }
# {
#   "Saignon": []
# }
# {
#   "Khulna": []
# }
# {
#   "Cam Ranh": []
# }
# {
#   "Philippines": [
#     {
#       "Manila": []
#     },
#     {
#       "Puerto Princesa": [
#         {
#           "Puerto Princesa City": []
#         }
#       ]
#     },
#     {
#       "Cebu": [
#         {
#           "Bantayan": []
#         }
#       ]
#     },
#     {
#       "Iloilo": [
#         {
#           "Oton": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Szeged": []
# }
# {
#   "Békéscsaba": []
# }
# {
#   "Washington": [
#     {
#       "Seattle": []
#     },
#     {
#       "Tacoma": []
#     },
#     {
#       "Port Orchard": []
#     },
#     {
#       "Friday Harbor": []
#     },
#     {
#       "Bellevue": []
#     }
#   ]
# }
# {
#   "Taoyuan": [
#     {
#       "Taoyuan District": []
#     }
#   ]
# }
# {
#   "Kim Thanh": []
# }
# {
#   "Gò Quao": []
# }
# {
#   "Bekasi": []
# }
# {
#   "Spain": [
#     {
#       "Madrid": [
#         {
#           "Campo Real": []
#         }
#       ]
#     },
#     {
#       "Algeciras": []
#     }
#   ]
# }
# {
#   "Mu Cang Chai": []
# }
# {
#   "Vinh Yen": []
# }
# {
#   "Thap Muoi": []
# }
# {
#   "Cao Xá": []
# }
# {
#   "Székesfehérvár": []
# }
# {
#   "Gò Công": []
# }
# {
#   "La Goulette": []
# }
# {
#   "Chí Linh": []
# }
# {
#   "Florida": [
#     {
#       "Dade City": []
#     },
#     {
#       "Brandon": []
#     },
#     {
#       "Miami": []
#     },
#     {
#       "Tampa": []
#     },
#     {
#       "Italia": []
#     },
#     {
#       "Vero Beach": []
#     },
#     {
#       "Miramar": []
#     },
#     {
#       "Gainesville": []
#     },
#     {
#       "West Palm Beach": []
#     }
#   ]
# }
# {
#   "Quy Chau": []
# }
# {
#   "Albertirsa": []
# }
# {
#   "Wolverhampton": []
# }
# {
#   "Cai Lay": []
# }
# {
#   "Tan Phuoc": []
# }
# {
#   "Georgia": [
#     {
#       "Atlanta": []
#     },
#     {
#       "Columbus": []
#     },
#     {
#       "Peachtree City": []
#     },
#     {
#       "Acworth": []
#     }
#   ]
# }
# {
#   "Poland": [
#     {
#       "Kielce": []
#     },
#     {
#       "Warszawa": [
#         {
#           "Stefanowo": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Guyana": [
#     {
#       "Georgetown": []
#     }
#   ]
# }
# {
#   "Mártély": []
# }
# {
#   "Gyor": []
# }
# {
#   "Vi Thanh": []
# }
# {
#   "Machala": []
# }
# {
#   "Batangas": [
#     {
#       "Rosario": []
#     }
#   ]
# }
# {
#   "Dsegh": []
# }
# {
#   "Kota Kinabalu": []
# }
# {
#   "Tunisia": [
#     {
#       "Tunis": []
#     }
#   ]
# }
# {
#   "Hội An": []
# }
# {
#   "Pangala": []
# }
# {
#   "Son Tinh": []
# }
# {
#   "Pekalongan": []
# }
# {
#   "Etyek": []
# }
# {
#   "Shinjuku": []
# }
# {
#   "Maryland": [
#     {
#       "Baltimore": []
#     },
#     {
#       "Rockville": []
#     },
#     {
#       "California": []
#     }
#   ]
# }
# {
#   "Bandar Lampung": []
# }
# {
#   "Serang": []
# }
# {
#   "Ethiopia": [
#     {
#       "Addis Ababa": []
#     }
#   ]
# }
# {
#   "Tân Hòa": []
# }
# {
#   "Batu (city)": []
# }
# {
#   "Rio de Janeiro": [
#     {
#       "Rio de Janeiro": []
#     }
#   ]
# }
# {
#   "Nebraska": [
#     {
#       "Omaha": []
#     }
#   ]
# }
# {
#   "Szentes": []
# }
# {
#   "Pennsylvania": [
#     {
#       "Lancaster": []
#     },
#     {
#       "State College": []
#     },
#     {
#       "Philadelphia": []
#     },
#     {
#       "West Chester": []
#     },
#     {
#       "Pittsburgh": []
#     }
#   ]
# }
# {
#   "Jaboatão dos Guararapes": []
# }
# {
#   "Kanagawa": [
#     {
#       "Yokosuka": []
#     },
#     {
#       "Chigasaki": []
#     }
#   ]
# }
# {
#   "Thanh Son": []
# }
# {
#   "Lam Ha": []
# }
# {
#   "Ky Anh": []
# }
# {
#   "Guangdong": [
#     {
#       "Shenzhen": []
#     }
#   ]
# }
# {
#   "Kentucky": [
#     {
#       "Louisville": []
#     }
#   ]
# }
# {
#   "Lái Thiêu": []
# }
# {
#   "Utah": [
#     {
#       "Park City": []
#     }
#   ]
# }
# {
#   "Tinh Bien": []
# }
# {
#   "Vung Liem": []
# }
# {
#   "Virginia": [
#     {
#       "Falls Church": []
#     }
#   ]
# }
# {
#   "Sarawak": [
#     {
#       "Dalat": []
#     },
#     {
#       "Miri": []
#     }
#   ]
# }
# {
#   "Lattakia": []
# }
# {
#   "General Santos City": []
# }
# {
#   "Massachusetts": [
#     {
#       "Boston": []
#     },
#     {
#       "Belmont": []
#     },
#     {
#       "Lynn": []
#     },
#     {
#       "Haverhill": []
#     },
#     {
#       "Milford": []
#     },
#     {
#       "Worcester": []
#     },
#     {
#       "Walpole": []
#     },
#     {
#       "Tewksbury": []
#     },
#     {
#       "Cambridge": []
#     },
#     {
#       "Hyde Park": []
#     },
#     {
#       "Easton": []
#     },
#     {
#       "Lawrence": []
#     },
#     {
#       "Harwich": []
#     }
#   ]
# }
# {
#   "Gujarat": [
#     {
#       "Surat": []
#     }
#   ]
# }
# {
#   "Illinois": [
#     {
#       "Normal": []
#     },
#     {
#       "Chicago": []
#     },
#     {
#       "Naperville": []
#     }
#   ]
# }
# {
#   "Hyderabad": []
# }
# {
#   "Oklahoma": [
#     {
#       "Oklahoma City": []
#     },
#     {
#       "Newcastle": []
#     },
#     {
#       "Yukon": []
#     }
#   ]
# }
# {
#   "Batangas City": []
# }
# {
#   "Bogra": []
# }
# {
#   "Kolkata": []
# }
# {
#   "Karlovy Vary": []
# }
# {
#   "Chon Thanh": []
# }
# {
#   "Venezuela": [
#     {
#       "Rubio": []
#     }
#   ]
# }
# {
#   "Angola": [
#     {
#       "Luanda": []
#     },
#     {
#       "Huambo": [
#         {
#           "Nova Lisboa": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Maine": [
#     {
#       "South Portland": []
#     },
#     {
#       "Fort Kent": []
#     },
#     {
#       "Rockland": []
#     },
#     {
#       "Augusta": []
#     },
#     {
#       "Ellsworth": []
#     },
#     {
#       "Auburn": []
#     }
#   ]
# }
# {
#   "Gorontalo": []
# }
# {
#   "Yen Thuy": []
# }
# {
#   "Probolinggo": []
# }
# {
#   "Gifu": [
#     {
#       "Mino": []
#     }
#   ]
# }
# {
#   "Spijkenisse": []
# }
# {
#   "District of Columbia": [
#     {
#       "Washington": []
#     }
#   ]
# }
# {
#   "Sam Son": []
# }
# {
#   "Wisconsin": [
#     {
#       "Milwaukee": []
#     }
#   ]
# }
# {
#   "Sharjah": []
# }
# {
#   "Rhode Island": [
#     {
#       "Cranston": []
#     },
#     {
#       "Newport": []
#     }
#   ]
# }
# {
#   "Palembang": []
# }
# {
#   "Yilan City": []
# }
# {
#   "Oman": [
#     {
#       "Masqaţ": [
#         {
#           "Qurayyat": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Gresik": []
# }
# {
#   "Güzelbahçe": []
# }
# {
#   "Norway": [
#     {
#       "Oslo": []
#     }
#   ]
# }
# {
#   "Que Phong": []
# }
# {
#   "Khanewal": []
# }
# {
#   "Adana": []
# }
# {
#   "Thanh Ba": []
# }
# {
#   "Sông Mã": []
# }
# {
#   "Thanh Thuy": []
# }
# {
#   "Diourbel": []
# }
# {
#   "Louisiana": [
#     {
#       "Baton Rouge": []
#     },
#     {
#       "Monroe": []
#     }
#   ]
# }
# {
#   "Hiroshima": []
# }
# {
#   "Anseong": []
# }
# {
#   "Yogyakarta": []
# }
# {
#   "Tien Lu": []
# }
# {
#   "Portugal": [
#     {
#       "Lisbon": [
#         {
#           "Almada": []
#         }
#       ]
#     },
#     {
#       "Aveiro": [
#         {
#           "Feira": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Denmark": [
#     {
#       "Aarhus": []
#     }
#   ]
# }
# {
#   "Uông Bí": []
# }
# {
#   "Kaposvár": []
# }
# {
#   "Monaco": [
#     {
#       "Monte-Carlo": []
#     }
#   ]
# }
# {
#   "Mpumalanga": [
#     {
#       "Nelspruit": []
#     }
#   ]
# }
# {
#   "Ernakulam": []
# }
# {
#   "Cilegon": []
# }
# {
#   "New Zealand": [
#     {
#       "Auckland": []
#     },
#     {
#       "Wellington": []
#     }
#   ]
# }
# {
#   "Van Chan": []
# }
# {
#   "Hai Hau": []
# }
# {
#   "Pohang": []
# }
# {
#   "Purwakarta": []
# }
# {
#   "Colorado": [
#     {
#       "Lakewood": []
#     }
#   ]
# }
# {
#   "Fukuoka": [
#     {
#       "Kurume": []
#     }
#   ]
# }
# {
#   "Connecticut": [
#     {
#       "New Haven": []
#     }
#   ]
# }
# {
#   "Maharashtra": [
#     {
#       "Mumbai": []
#     }
#   ]
# }
# {
#   "New Hampshire": [
#     {
#       "Portsmouth": []
#     },
#     {
#       "Gilford": []
#     }
#   ]
# }
# {
#   "United Arab Emirates": [
#     {
#       "Dubai": []
#     }
#   ]
# }
# {
#   "Bulacan": [
#     {
#       "Calumpit": []
#     }
#   ]
# }
# {
#   "Guar Chempedak": []
# }
# {
#   "Cho Gao": []
# }
# {
#   "Gauteng": [
#     {
#       "Johannesburg": []
#     }
#   ]
# }
# {
#   "Carmen de Patagones": []
# }
# {
#   "Burma": [
#     {
#       "Shan State": [
#         {
#           "Pang-Lashio": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Tennessee": [
#     {
#       "Nashville": []
#     },
#     {
#       "Murfreesboro": []
#     },
#     {
#       "Tennessee City": []
#     }
#   ]
# }
# {
#   "Tri Tôn": []
# }
# {
#   "Peru": [
#     {
#       "Cusco": []
#     },
#     {
#       "Lima": []
#     }
#   ]
# }
# {
#   "Dhandhuka": []
# }
# {
#   "Laguna": [
#     {
#       "Santa Rosa": []
#     }
#   ]
# }
# {
#   "Kadal": []
# }
# {
#   "Quistello": []
# }
# {
#   "Bim Son": []
# }
# {
#   "Chiapas": [
#     {
#       "Tuxtla Gutiérrez": []
#     }
#   ]
# }
# {
#   "Cameroon": [
#     {
#       "Yaoundé": []
#     }
#   ]
# }
# {
#   "Sweden": [
#     {
#       "Stockholm": []
#     }
#   ]
# }
# {
#   "Thai Hoa": []
# }
# {
#   "Southern Leyte": [
#     {
#       "Maasin": []
#     }
#   ]
# }
# {
#   "Vinh Cuu": []
# }
# {
#   "Xuyen Moc": []
# }
# {
#   "Luc Yen": []
# }
# {
#   "Lac Thuy": []
# }
# {
#   "Lap Thach": []
# }
# {
#   "Cincinnati": []
# }
# {
#   "Ohio": [
#     {
#       "Cleveland": []
#     },
#     {
#       "Berlin Heights": []
#     },
#     {
#       "Dayton": []
#     }
#   ]
# }
# {
#   "Batu Pahat": []
# }
# {
#   "Ha Hoa": []
# }
# {
#   "Devon": [
#     {
#       "Exeter": []
#     }
#   ]
# }
# {
#   "Mai Son": []
# }
# {
#   "Kinh Môn": []
# }
# {
#   "Sylhet": []
# }
# {
#   "Cayman Islands": [
#     {
#       "George Town": []
#     }
#   ]
# }
# {
#   "Bor-et-Bar": []
# }
# {
#   "Bidar": []
# }
# {
#   "Hessen": [
#     {
#       "Offenbach": []
#     }
#   ]
# }
# {
#   "Costa Rica": [
#     {
#       "San Jose": [
#         {
#           "Desamparados": []
#         }
#       ]
#     },
#     {
#       "Puntarenas": [
#         {
#           "Laurel": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Banjarmasin": []
# }
# {
#   "Las Piñas": []
# }
# {
#   "Holywood": []
# }
# {
#   "New Jersey": [
#     {
#       "Marlton": []
#     }
#   ]
# }
# {
#   "Bao Yen": []
# }
# {
#   "Hai Lang": []
# }
# {
#   "Oregon": [
#     {
#       "Portland": []
#     }
#   ]
# }
# {
#   "Inzai": []
# }
# {
#   "Slovakia": [
#     {
#       "Bratislava": []
#     }
#   ]
# }
# {
#   "Tien Hai": []
# }
# {
#   "Meo Vac": []
# }
# {
#   "Kuantan": []
# }
# {
#   "Zhongshan": []
# }
# {
#   "Paraguay": [
#     {
#       "Asunción": []
#     }
#   ]
# }
# {
#   "Na Hang": []
# }
# {
#   "Chaco": [
#     {
#       "Resistencia": []
#     }
#   ]
# }
# {
#   "Karnataka": [
#     {
#       "Mysore": []
#     }
#   ]
# }
# {
#   "Rohtak": []
# }
# {
#   "Londrina": []
# }
# {
#   "Binh Thuy": []
# }
# {
#   "Hoang Hoa": []
# }
# {
#   "Mabinay": []
# }
# {
#   "Gorakhpur": []
# }
# {
#   "An Nhon": []
# }
# {
#   "Bucheon": []
# }
# {
#   "Beni Suef": []
# }
# {
#   "Jijel": []
# }
# {
#   "Mississippi": [
#     {
#       "Jackson": []
#     }
#   ]
# }
# {
#   "Chbar Mon (town)": []
# }
# {
#   "Yên Châu": []
# }
# {
#   "Salto de Pirapora": []
# }
# {
#   "Kansas": [
#     {
#       "Wichita": []
#     }
#   ]
# }
# {
#   "Gwangju": []
# }
# {
#   "Hà Tiên": []
# }
# {
#   "Levallois-Perret": []
# }
# {
#   "Makassar": []
# }
# {
#   "Nanning": []
# }
# {
#   "Mbeya": []
# }
# {
#   "Palangkaraya": []
# }
# {
#   "Pokaran": []
# }
# {
#   "Puchong": []
# }
# {
#   "Seremban (City)": []
# }
# {
#   "Missouri": [
#     {
#       "Ballwin": []
#     }
#   ]
# }
# {
#   "Pattaya": []
# }
# {
#   "Ilocos Sur": [
#     {
#       "Candon": []
#     }
#   ]
# }
# {
#   "Sampit": []
# }
# {
#   "Phu Luong": []
# }
# {
#   "Cirebon": []
# }
# {
#   "Papua New Guinea": [
#     {
#       "Southern Highlands": [
#         {
#           "Hanoi": []
#         }
#       ]
#     },
#     {
#       "Port Moresby": []
#     }
#   ]
# }
# {
#   "St. Louis": []
# }
# {
#   "Isabela": [
#     {
#       "Roxas": []
#     }
#   ]
# }
# {
#   "Tampines New Town": []
# }
# {
#   "Siedlce": []
# }
# {
#   "Chile": [
#     {
#       "Las Condes": []
#     }
#   ]
# }
# {
#   "Cam Thuy": []
# }
# {
#   "Makilala": []
# }
# {
#   "Quang Trach": []
# }
# {
#   "Salatiga": []
# }
# {
#   "Seongnam": []
# }
# {
#   "Cambodia": [
#     {
#       "Phnum Penh": [
#         {
#           "Phnum Pénh": []
#         }
#       ]
#     }
#   ]
# }
# {
#   "Cantabria": [
#     {
#       "Santander": []
#     }
#   ]
# }
# {
#   "Gothenburg": []
# }
# {
#   "Sindh": [
#     {
#       "Hyderabad": []
#     }
#   ]
# }
# {
#   "Shubra al Khaymah": []
# }
# {
#   "Sichuan": [
#     {
#       "Chengdu": []
#     }
#   ]
# }
# {
#   "Tabaco": []
# }
# {
#   "Giao Thuy": []
# }
# {
#   "Kangar": []
# }
# {
#   "Tangail": []
# }
# {
#   "Saou": []
# }
# {
#   "Attopeu": []
# }
# {
#   "Szentendre": []
# }
# {
#   "Tuyên Hóa": []
# }
# {
#   "Nawalapitiya": []
# }
# {
#   "Azerbaijan": [
#     {
#       "Baku": []
#     }
#   ]
# }
# {
#   "Plymouth": []
# }
# {
#   "Nga Son": []
# }
# {
#   "Port Douglas": []
# }
# {
#   "Trieu Phong": []
# }
